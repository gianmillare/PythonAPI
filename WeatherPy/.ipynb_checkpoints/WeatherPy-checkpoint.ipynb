# %%
# Dependencies
import os
import csv
import json
import requests

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pprint import pprint
from apikey import apikey
from citipy import citipy

latrange = (-90, 90)
lngrange = (-180, 180)

# %%
# Given Information
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 606

# %%
# Set quantifiable data equal to Zero
record = 0
recordset = 0

latitude = []
longitude = []
temperature = []
cloudiness = []
humidity = []
windspeed = []
date = []
cityxyz = []
country = []

# %%
# Testing URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + apikey
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f001ac5c2e40c2622d097358ae09b387'

# %%
# Testing query URL
query = f"{url}&q={city}"
query
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f001ac5c2e40c2622d097358ae09b387&q=barentsburg'

# %%
# Testing JSON function
response = requests.get(query).json()
pprint(response)
# Out:
# {'cod': '404', 'message': 'city not found'}

# %%
# Create For Loop
print('---------------------------------------------------------------------------------')

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + apikey 

for city in cities:
    
    query_url = url + "&q=" + city
    responsejson = requests.get(query_url).json()
    
    if record < 50:
        record = record + 1
    else:
        recordset = recordset + 1
        record = 0

    print('Processing record ' + str(record) + ' of set ' + str(recordset) + ' -----> ' + city)

    try:
        latitude.append(responsejson['coord']['lat'])
        longitude.append(responsejson['coord']['lon'])
        temperature.append(responsejson['main']['temp_max'])
        humidity.append(responsejson['main']['humidity'])
        cloudiness.append(responsejson['clouds']['all'])
        windspeed.append(responsejson['wind']['speed'])
        date.append(responsejson['dt'])
        country.append(responsejson['sys']['country'])
        cityxyz.append(city)

    except:
        print("City not found. Skipping...")
        pass

print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Processing record 1 of set 0 -----> saldanha
# Processing record 2 of set 0 -----> mataura
# Processing record 3 of set 0 -----> barrow
# Processing record 4 of set 0 -----> luderitz
# Processing record 5 of set 0 -----> vaini
# Processing record 6 of set 0 -----> sitka
# Processing record 7 of set 0 -----> port alfred
# Processing record 8 of set 0 -----> along
# Processing record 9 of set 0 -----> hobart
# Processing record 10 of set 0 -----> tombouctou
# Processing record 11 of set 0 -----> rikitea
# Processing record 12 of set 0 -----> port elizabeth
# Processing record 13 of set 0 -----> taolanaro
# City not found. Skipping...
# Processing record 14 of set 0 -----> maraa
# Processing record 15 of set 0 -----> tarare
# Processing record 16 of set 0 -----> qaanaaq
# Processing record 17 of set 0 -----> hermanus
# Processing record 18 of set 0 -----> stanger
# Processing record 19 of set 0 -----> albany
# Processing record 20 of set 0 -----> adrar
# Processing record 21 of set 0 -----> mergui
# City not found. Skipping...
# Processing record 22 of set 0 -----> punta arenas
# Processing record 23 of set 0 -----> upernavik
# Processing record 24 of set 0 -----> sesimbra
# Processing record 25 of set 0 -----> ixtapa
# Processing record 26 of set 0 -----> port hardy
# Processing record 27 of set 0 -----> jerome
# Processing record 28 of set 0 -----> atuona
# Processing record 29 of set 0 -----> pevek
# Processing record 30 of set 0 -----> jamestown
# Processing record 31 of set 0 -----> hilo
# Processing record 32 of set 0 -----> barentsburg
# City not found. Skipping...
# Processing record 33 of set 0 -----> butaritari
# Processing record 34 of set 0 -----> viligili
# City not found. Skipping...
# Processing record 35 of set 0 -----> broken hill
# Processing record 36 of set 0 -----> yellowknife
# Processing record 37 of set 0 -----> chuy
# Processing record 38 of set 0 -----> shalya
# Processing record 39 of set 0 -----> tigil
# Processing record 40 of set 0 -----> tumannyy
# City not found. Skipping...
# Processing record 41 of set 0 -----> provideniya
# Processing record 42 of set 0 -----> tasbuget
# City not found. Skipping...
# Processing record 43 of set 0 -----> lorengau
# Processing record 44 of set 0 -----> tasiilaq
# Processing record 45 of set 0 -----> cabo san lucas
# Processing record 46 of set 0 -----> helena
# Processing record 47 of set 0 -----> benjamin constant
# Processing record 48 of set 0 -----> geraldton
# Processing record 49 of set 0 -----> churapcha
# Processing record 50 of set 0 -----> sibu
# Processing record 0 of set 1 -----> aripuana
# Processing record 1 of set 1 -----> saint-louis
# Processing record 2 of set 1 -----> saint-augustin
# Processing record 3 of set 1 -----> tarnogskiy gorodok
# Processing record 4 of set 1 -----> ningan
# City not found. Skipping...
# Processing record 5 of set 1 -----> imbituba
# Processing record 6 of set 1 -----> umm lajj
# Processing record 7 of set 1 -----> westport
# Processing record 8 of set 1 -----> thompson
# Processing record 9 of set 1 -----> vostok
# Processing record 10 of set 1 -----> bethel
# Processing record 11 of set 1 -----> salalah
# Processing record 12 of set 1 -----> busselton
# Processing record 13 of set 1 -----> new norfolk
# Processing record 14 of set 1 -----> laredo
# Processing record 15 of set 1 -----> vila
# Processing record 16 of set 1 -----> ushuaia
# Processing record 17 of set 1 -----> naze
# Processing record 18 of set 1 -----> alyangula
# Processing record 19 of set 1 -----> bluff
# Processing record 20 of set 1 -----> amderma
# City not found. Skipping...
# Processing record 21 of set 1 -----> ust-nera
# Processing record 22 of set 1 -----> torbay
# Processing record 23 of set 1 -----> ancud
# Processing record 24 of set 1 -----> sept-iles
# Processing record 25 of set 1 -----> ahuimanu
# Processing record 26 of set 1 -----> iraucuba
# Processing record 27 of set 1 -----> bredasdorp
# Processing record 28 of set 1 -----> airai
# Processing record 29 of set 1 -----> tsihombe
# City not found. Skipping...
# Processing record 30 of set 1 -----> vardo
# Processing record 31 of set 1 -----> mount pleasant
# Processing record 32 of set 1 -----> saskylakh
# Processing record 33 of set 1 -----> mayo
# Processing record 34 of set 1 -----> victoria
# Processing record 35 of set 1 -----> lagoa
# Processing record 36 of set 1 -----> seoul
# Processing record 37 of set 1 -----> henties bay
# Processing record 38 of set 1 -----> grindavik
# Processing record 39 of set 1 -----> lebu
# Processing record 40 of set 1 -----> yining
# Processing record 41 of set 1 -----> sena madureira
# Processing record 42 of set 1 -----> cape town
# Processing record 43 of set 1 -----> carballo
# Processing record 44 of set 1 -----> desdunes
# Processing record 45 of set 1 -----> severo-kurilsk
# Processing record 46 of set 1 -----> isla mujeres
# Processing record 47 of set 1 -----> kodiak
# Processing record 48 of set 1 -----> barbar
# City not found. Skipping...
# Processing record 49 of set 1 -----> bilibino
# Processing record 50 of set 1 -----> iqaluit
# Processing record 0 of set 2 -----> kapaa
# Processing record 1 of set 2 -----> antofagasta
# Processing record 2 of set 2 -----> klaksvik
# Processing record 3 of set 2 -----> arraial do cabo
# Processing record 4 of set 2 -----> fayaoue
# Processing record 5 of set 2 -----> rocha
# Processing record 6 of set 2 -----> mount gambier
# Processing record 7 of set 2 -----> duki
# Processing record 8 of set 2 -----> tuktoyaktuk
# Processing record 9 of set 2 -----> okha
# Processing record 10 of set 2 -----> georgetown
# Processing record 11 of set 2 -----> bara
# Processing record 12 of set 2 -----> ahipara
# Processing record 13 of set 2 -----> iranshahr
# Processing record 14 of set 2 -----> aklavik
# Processing record 15 of set 2 -----> bandarbeyla
# Processing record 16 of set 2 -----> san patricio
# Processing record 17 of set 2 -----> necochea
# Processing record 18 of set 2 -----> luanda
# Processing record 19 of set 2 -----> illoqqortoormiut
# City not found. Skipping...
# Processing record 20 of set 2 -----> faanui
# Processing record 21 of set 2 -----> beian
# Processing record 22 of set 2 -----> nikolskoye
# Processing record 23 of set 2 -----> port blair
# Processing record 24 of set 2 -----> pangai
# Processing record 25 of set 2 -----> yulara
# Processing record 26 of set 2 -----> oranjemund
# Processing record 27 of set 2 -----> kawalu
# Processing record 28 of set 2 -----> longyearbyen
# Processing record 29 of set 2 -----> muroto
# Processing record 30 of set 2 -----> banda aceh
# Processing record 31 of set 2 -----> guerrero negro
# Processing record 32 of set 2 -----> puerto ayora
# Processing record 33 of set 2 -----> codrington
# Processing record 34 of set 2 -----> fukue
# Processing record 35 of set 2 -----> tecpan
# Processing record 36 of set 2 -----> khatanga
# Processing record 37 of set 2 -----> tocopilla
# Processing record 38 of set 2 -----> hithadhoo
# Processing record 39 of set 2 -----> castro
# Processing record 40 of set 2 -----> tuatapere
# Processing record 41 of set 2 -----> ilhabela
# Processing record 42 of set 2 -----> murray
# Processing record 43 of set 2 -----> harrisonburg
# Processing record 44 of set 2 -----> clyde river
# Processing record 45 of set 2 -----> jian
# Processing record 46 of set 2 -----> kaitangata
# Processing record 47 of set 2 -----> kenai
# Processing record 48 of set 2 -----> mar del plata
# Processing record 49 of set 2 -----> san cristobal
# Processing record 50 of set 2 -----> correia pinto
# Processing record 0 of set 3 -----> dikson
# Processing record 1 of set 3 -----> goianapolis
# Processing record 2 of set 3 -----> kamogawa
# Processing record 3 of set 3 -----> katsuura
# Processing record 4 of set 3 -----> griffith
# Processing record 5 of set 3 -----> bambous virieux
# Processing record 6 of set 3 -----> faya
# Processing record 7 of set 3 -----> berdigestyakh
# Processing record 8 of set 3 -----> saint-philippe
# Processing record 9 of set 3 -----> hunza
# City not found. Skipping...
# Processing record 10 of set 3 -----> belushya guba
# City not found. Skipping...
# Processing record 11 of set 3 -----> tolmachevo
# Processing record 12 of set 3 -----> port-cartier
# Processing record 13 of set 3 -----> vanimo
# Processing record 14 of set 3 -----> tottori
# Processing record 15 of set 3 -----> olafsvik
# City not found. Skipping...
# Processing record 16 of set 3 -----> ilulissat
# Processing record 17 of set 3 -----> fontenay-le-comte
# Processing record 18 of set 3 -----> tallahassee
# Processing record 19 of set 3 -----> saint-paul
# Processing record 20 of set 3 -----> beringovskiy
# Processing record 21 of set 3 -----> lufilufi
# Processing record 22 of set 3 -----> san quintin
# Processing record 23 of set 3 -----> wanning
# Processing record 24 of set 3 -----> altagracia de orituco
# Processing record 25 of set 3 -----> bismarck
# Processing record 26 of set 3 -----> ulladulla
# Processing record 27 of set 3 -----> great yarmouth
# Processing record 28 of set 3 -----> mundi
# Processing record 29 of set 3 -----> bargal
# City not found. Skipping...
# Processing record 30 of set 3 -----> avarua
# Processing record 31 of set 3 -----> hihifo
# City not found. Skipping...
# Processing record 32 of set 3 -----> dien bien
# City not found. Skipping...
# Processing record 33 of set 3 -----> markova
# Processing record 34 of set 3 -----> louisbourg
# City not found. Skipping...
# Processing record 35 of set 3 -----> honningsvag
# Processing record 36 of set 3 -----> bathsheba
# Processing record 37 of set 3 -----> lompoc
# Processing record 38 of set 3 -----> suileng
# Processing record 39 of set 3 -----> santa vitoria do palmar
# Processing record 40 of set 3 -----> mys shmidta
# City not found. Skipping...
# Processing record 41 of set 3 -----> sur
# Processing record 42 of set 3 -----> grand river south east
# City not found. Skipping...
# Processing record 43 of set 3 -----> saint anthony
# Processing record 44 of set 3 -----> redwater
# Processing record 45 of set 3 -----> petropavlovsk-kamchatskiy
# Processing record 46 of set 3 -----> kyshtym
# Processing record 47 of set 3 -----> auckland
# Processing record 48 of set 3 -----> lavrentiya
# Processing record 49 of set 3 -----> poum
# Processing record 50 of set 3 -----> zaysan
# Processing record 0 of set 4 -----> jaleswar
# Processing record 1 of set 4 -----> attawapiskat
# City not found. Skipping...
# Processing record 2 of set 4 -----> kutum
# Processing record 3 of set 4 -----> abnub
# Processing record 4 of set 4 -----> krasnoselkup
# City not found. Skipping...
# Processing record 5 of set 4 -----> norman wells
# Processing record 6 of set 4 -----> zapolyarnyy
# Processing record 7 of set 4 -----> hatillo
# Processing record 8 of set 4 -----> killybegs
# Processing record 9 of set 4 -----> hofn
# Processing record 10 of set 4 -----> sao filipe
# Processing record 11 of set 4 -----> ozernovskiy
# Processing record 12 of set 4 -----> bone
# Processing record 13 of set 4 -----> newport
# Processing record 14 of set 4 -----> belyy yar
# Processing record 15 of set 4 -----> mount isa
# Processing record 16 of set 4 -----> campoverde
# Processing record 17 of set 4 -----> carnarvon
# Processing record 18 of set 4 -----> aitape
# Processing record 19 of set 4 -----> kattivakkam
# Processing record 20 of set 4 -----> edgewater
# Processing record 21 of set 4 -----> lima
# Processing record 22 of set 4 -----> vila velha
# Processing record 23 of set 4 -----> husavik
# Processing record 24 of set 4 -----> mathathane
# Processing record 25 of set 4 -----> namibe
# Processing record 26 of set 4 -----> praia da vitoria
# Processing record 27 of set 4 -----> sorland
# Processing record 28 of set 4 -----> shache
# Processing record 29 of set 4 -----> ponta do sol
# Processing record 30 of set 4 -----> yakeshi
# Processing record 31 of set 4 -----> laives
# Processing record 32 of set 4 -----> fortuna
# Processing record 33 of set 4 -----> thinadhoo
# Processing record 34 of set 4 -----> portel
# Processing record 35 of set 4 -----> zholymbet
# Processing record 36 of set 4 -----> jaisalmer
# Processing record 37 of set 4 -----> ballitoville
# Processing record 38 of set 4 -----> dawei
# Processing record 39 of set 4 -----> bac lieu
# City not found. Skipping...
# Processing record 40 of set 4 -----> wulanhaote
# City not found. Skipping...
# Processing record 41 of set 4 -----> falam
# Processing record 42 of set 4 -----> bowling green
# Processing record 43 of set 4 -----> ponta delgada
# Processing record 44 of set 4 -----> marovoay
# Processing record 45 of set 4 -----> kaseda
# Processing record 46 of set 4 -----> hanmer springs
# Processing record 47 of set 4 -----> nara
# Processing record 48 of set 4 -----> bredy
# Processing record 49 of set 4 -----> palabuhanratu
# City not found. Skipping...
# Processing record 50 of set 4 -----> magadan
# Processing record 0 of set 5 -----> ca mau
# Processing record 1 of set 5 -----> carutapera
# Processing record 2 of set 5 -----> arroyo
# Processing record 3 of set 5 -----> porto seguro
# Processing record 4 of set 5 -----> roma
# Processing record 5 of set 5 -----> shemysheyka
# Processing record 6 of set 5 -----> portland
# Processing record 7 of set 5 -----> kavaratti
# Processing record 8 of set 5 -----> khovu-aksy
# Processing record 9 of set 5 -----> pisco
# Processing record 10 of set 5 -----> washington
# Processing record 11 of set 5 -----> nador
# Processing record 12 of set 5 -----> chabahar
# Processing record 13 of set 5 -----> saint george
# Processing record 14 of set 5 -----> jasper
# Processing record 15 of set 5 -----> priiskovyy
# Processing record 16 of set 5 -----> praia
# Processing record 17 of set 5 -----> nizhneyansk
# City not found. Skipping...
# Processing record 18 of set 5 -----> juarez
# Processing record 19 of set 5 -----> isparta
# Processing record 20 of set 5 -----> snasa
# Processing record 21 of set 5 -----> kamenskoye
# City not found. Skipping...
# Processing record 22 of set 5 -----> ucluelet
# Processing record 23 of set 5 -----> tiksi
# Processing record 24 of set 5 -----> cidreira
# Processing record 25 of set 5 -----> shanhetun
# Processing record 26 of set 5 -----> constitucion
# Processing record 27 of set 5 -----> yerbogachen
# Processing record 28 of set 5 -----> tupik
# Processing record 29 of set 5 -----> nanortalik
# Processing record 30 of set 5 -----> amarante do maranhao
# Processing record 31 of set 5 -----> zhashkiv
# Processing record 32 of set 5 -----> beloha
# Processing record 33 of set 5 -----> caravelas
# Processing record 34 of set 5 -----> aguimes
# Processing record 35 of set 5 -----> paamiut
# Processing record 36 of set 5 -----> east london
# Processing record 37 of set 5 -----> esperance
# Processing record 38 of set 5 -----> tungkang
# City not found. Skipping...
# Processing record 39 of set 5 -----> calvinia
# Processing record 40 of set 5 -----> saint-joseph
# Processing record 41 of set 5 -----> ingham
# Processing record 42 of set 5 -----> simao
# Processing record 43 of set 5 -----> sorvag
# City not found. Skipping...
# Processing record 44 of set 5 -----> kansanshi
# Processing record 45 of set 5 -----> soyo
# Processing record 46 of set 5 -----> narsaq
# Processing record 47 of set 5 -----> iquique
# Processing record 48 of set 5 -----> dum duma
# Processing record 49 of set 5 -----> hami
# Processing record 50 of set 5 -----> kenora
# Processing record 0 of set 6 -----> yumen
# Processing record 1 of set 6 -----> boralday
# Processing record 2 of set 6 -----> dingle
# Processing record 3 of set 6 -----> gayeri
# Processing record 4 of set 6 -----> srandakan
# Processing record 5 of set 6 -----> sakakah
# City not found. Skipping...
# Processing record 6 of set 6 -----> makakilo city
# Processing record 7 of set 6 -----> carman
# Processing record 8 of set 6 -----> barra de sao francisco
# Processing record 9 of set 6 -----> nemuro
# Processing record 10 of set 6 -----> tutoia
# Processing record 11 of set 6 -----> talnakh
# Processing record 12 of set 6 -----> cherskiy
# Processing record 13 of set 6 -----> yankton
# Processing record 14 of set 6 -----> tubruq
# City not found. Skipping...
# Processing record 15 of set 6 -----> hukuntsi
# Processing record 16 of set 6 -----> leningradskiy
# Processing record 17 of set 6 -----> belmonte
# Processing record 18 of set 6 -----> barra do garcas
# Processing record 19 of set 6 -----> kahului
# Processing record 20 of set 6 -----> plattsburgh
# Processing record 21 of set 6 -----> bandar-e lengeh
# Processing record 22 of set 6 -----> itoman
# Processing record 23 of set 6 -----> maghama
# City not found. Skipping...
# Processing record 24 of set 6 -----> mutsamudu
# City not found. Skipping...
# Processing record 25 of set 6 -----> jalu
# Processing record 26 of set 6 -----> karatuzskoye
# Processing record 27 of set 6 -----> jatai
# Processing record 28 of set 6 -----> udachnyy
# Processing record 29 of set 6 -----> takaka
# Processing record 30 of set 6 -----> rajula
# Processing record 31 of set 6 -----> high level
# Processing record 32 of set 6 -----> sentyabrskiy
# City not found. Skipping...
# Processing record 33 of set 6 -----> nueve de julio
# Processing record 34 of set 6 -----> mahebourg
# Processing record 35 of set 6 -----> waingapu
# Processing record 36 of set 6 -----> karatau
# Processing record 37 of set 6 -----> buraydah
# Processing record 38 of set 6 -----> viedma
# Processing record 39 of set 6 -----> oyon
# Processing record 40 of set 6 -----> jiwani
# Processing record 41 of set 6 -----> tancheng
# Processing record 42 of set 6 -----> orange cove
# Processing record 43 of set 6 -----> puerto madryn
# Processing record 44 of set 6 -----> boca do acre
# Processing record 45 of set 6 -----> snina
# Processing record 46 of set 6 -----> dunedin
# Processing record 47 of set 6 -----> omboue
# Processing record 48 of set 6 -----> port keats
# Processing record 49 of set 6 -----> deputatskiy
# Processing record 50 of set 6 -----> muli
# Processing record 0 of set 7 -----> vestmannaeyjar
# Processing record 1 of set 7 -----> laguna
# Processing record 2 of set 7 -----> mayumba
# Processing record 3 of set 7 -----> lang son
# Processing record 4 of set 7 -----> bolpur
# Processing record 5 of set 7 -----> suntar
# Processing record 6 of set 7 -----> ostrovnoy
# Processing record 7 of set 7 -----> la ronge
# Processing record 8 of set 7 -----> marcona
# City not found. Skipping...
# Processing record 9 of set 7 -----> road town
# Processing record 10 of set 7 -----> divnoye
# Processing record 11 of set 7 -----> coahuayana
# Processing record 12 of set 7 -----> sao joao da barra
# Processing record 13 of set 7 -----> komsomolskoye
# Processing record 14 of set 7 -----> usinsk
# Processing record 15 of set 7 -----> ambovombe
# Processing record 16 of set 7 -----> chokurdakh
# Processing record 17 of set 7 -----> asau
# City not found. Skipping...
# Processing record 18 of set 7 -----> awjilah
# Processing record 19 of set 7 -----> khategaon
# Processing record 20 of set 7 -----> cedar city
# Processing record 21 of set 7 -----> ormara
# Processing record 22 of set 7 -----> polunochnoye
# Processing record 23 of set 7 -----> kushmurun
# City not found. Skipping...
# Processing record 24 of set 7 -----> baykit
# Processing record 25 of set 7 -----> ribeira grande
# Processing record 26 of set 7 -----> helong
# Processing record 27 of set 7 -----> vila franca do campo
# Processing record 28 of set 7 -----> shiyan
# Processing record 29 of set 7 -----> olinda
# Processing record 30 of set 7 -----> poronaysk
# Processing record 31 of set 7 -----> tarudant
# City not found. Skipping...
# Processing record 32 of set 7 -----> talaya
# Processing record 33 of set 7 -----> ambulu
# Processing record 34 of set 7 -----> maarianhamina
# City not found. Skipping...
# Processing record 35 of set 7 -----> yatou
# Processing record 36 of set 7 -----> najran
# Processing record 37 of set 7 -----> torrington
# Processing record 38 of set 7 -----> douglas
# Processing record 39 of set 7 -----> huarmey
# Processing record 40 of set 7 -----> san policarpo
# Processing record 41 of set 7 -----> ola
# Processing record 42 of set 7 -----> dzerzhinskoye
# Processing record 43 of set 7 -----> bonaventure
# Processing record 44 of set 7 -----> bengkulu
# City not found. Skipping...
# Processing record 45 of set 7 -----> toliary
# City not found. Skipping...
# Processing record 46 of set 7 -----> axim
# Processing record 47 of set 7 -----> manokwari
# Processing record 48 of set 7 -----> grand gaube
# Processing record 49 of set 7 -----> yenagoa
# Processing record 50 of set 7 -----> beyneu
# Processing record 0 of set 8 -----> progreso
# Processing record 1 of set 8 -----> singaparna
# Processing record 2 of set 8 -----> rio gallegos
# Processing record 3 of set 8 -----> cefalu
# Processing record 4 of set 8 -----> asheboro
# Processing record 5 of set 8 -----> te anau
# Processing record 6 of set 8 -----> hasaki
# Processing record 7 of set 8 -----> nur
# Processing record 8 of set 8 -----> cockburn town
# Processing record 9 of set 8 -----> karratha
# Processing record 10 of set 8 -----> chara
# Processing record 11 of set 8 -----> ushumun
# Processing record 12 of set 8 -----> riverton
# Processing record 13 of set 8 -----> aykhal
# Processing record 14 of set 8 -----> acapulco
# Processing record 15 of set 8 -----> rafai
# Processing record 16 of set 8 -----> buluang
# Processing record 17 of set 8 -----> port-gentil
# Processing record 18 of set 8 -----> coihaique
# Processing record 19 of set 8 -----> mineros
# Processing record 20 of set 8 -----> constantine
# Processing record 21 of set 8 -----> sterling
# Processing record 22 of set 8 -----> novoasbest
# Processing record 23 of set 8 -----> sibolga
# Processing record 24 of set 8 -----> lisala
# Processing record 25 of set 8 -----> tagusao
# Processing record 26 of set 8 -----> lata
# Processing record 27 of set 8 -----> homer
# Processing record 28 of set 8 -----> hamilton
# Processing record 29 of set 8 -----> sabancuy
# Processing record 30 of set 8 -----> lucapa
# Processing record 31 of set 8 -----> emerald
# Processing record 32 of set 8 -----> cangzhou
# Processing record 33 of set 8 -----> kayes
# Processing record 34 of set 8 -----> astorga
# Processing record 35 of set 8 -----> kazalinsk
# City not found. Skipping...
# Processing record 36 of set 8 -----> visnes
# Processing record 37 of set 8 -----> tivaouane
# Processing record 38 of set 8 -----> krasnoarmeysk
# Processing record 39 of set 8 -----> lyubymivka
# Processing record 40 of set 8 -----> broome
# Processing record 41 of set 8 -----> feijo
# Processing record 42 of set 8 -----> shambu
# Processing record 43 of set 8 -----> kavieng
# Processing record 44 of set 8 -----> sinnamary
# Processing record 45 of set 8 -----> tynda
# Processing record 46 of set 8 -----> malatya
# Processing record 47 of set 8 -----> fort nelson
# Processing record 48 of set 8 -----> marshall
# Processing record 49 of set 8 -----> capim grosso
# Processing record 50 of set 8 -----> rungata
# City not found. Skipping...
# Processing record 0 of set 9 -----> jega
# Processing record 1 of set 9 -----> itarema
# Processing record 2 of set 9 -----> taunggyi
# Processing record 3 of set 9 -----> mayma
# Processing record 4 of set 9 -----> bainbridge
# Processing record 5 of set 9 -----> rush
# Processing record 6 of set 9 -----> kinwat
# Processing record 7 of set 9 -----> banjar
# Processing record 8 of set 9 -----> cardoso
# Processing record 9 of set 9 -----> sandakan
# Processing record 10 of set 9 -----> souillac
# Processing record 11 of set 9 -----> takoradi
# Processing record 12 of set 9 -----> kotaparh
# Processing record 13 of set 9 -----> bakel
# Processing record 14 of set 9 -----> zeya
# Processing record 15 of set 9 -----> solovetskiy
# City not found. Skipping...
# Processing record 16 of set 9 -----> koumac
# Processing record 17 of set 9 -----> oia
# Processing record 18 of set 9 -----> maketu
# Processing record 19 of set 9 -----> lishu
# Processing record 20 of set 9 -----> chala
# Processing record 21 of set 9 -----> rio grande
# Processing record 22 of set 9 -----> vysokogornyy
# Processing record 23 of set 9 -----> potenza
# Processing record 24 of set 9 -----> kuytun
# Processing record 25 of set 9 -----> araouane
# Processing record 26 of set 9 -----> alice springs
# Processing record 27 of set 9 -----> necaxa
# Processing record 28 of set 9 -----> los llanos de aridane
# Processing record 29 of set 9 -----> naifaru
# Processing record 30 of set 9 -----> cabimas
# Processing record 31 of set 9 -----> melito di porto salvo
# Processing record 32 of set 9 -----> dondo
# Processing record 33 of set 9 -----> evensk
# Processing record 34 of set 9 -----> maneadero
# City not found. Skipping...
# Processing record 35 of set 9 -----> crotone
# Processing record 36 of set 9 -----> ondjiva
# Processing record 37 of set 9 -----> canton
# Processing record 38 of set 9 -----> kitoy
# Processing record 39 of set 9 -----> coulihaut
# City not found. Skipping...
# Processing record 40 of set 9 -----> warrington
# Processing record 41 of set 9 -----> benemerito de las americas
# Processing record 42 of set 9 -----> dingzhou
# Processing record 43 of set 9 -----> port shepstone
# Processing record 44 of set 9 -----> catemaco
# Processing record 45 of set 9 -----> dungarvan
# Processing record 46 of set 9 -----> dicabisagan
# Processing record 47 of set 9 -----> ozark
# Processing record 48 of set 9 -----> cabedelo
# Processing record 49 of set 9 -----> texarkana
# Processing record 50 of set 9 -----> teya
# Processing record 0 of set 10 -----> lumberton
# Processing record 1 of set 10 -----> khandyga
# Processing record 2 of set 10 -----> arman
# Processing record 3 of set 10 -----> worland
# Processing record 4 of set 10 -----> ginir
# Processing record 5 of set 10 -----> luwuk
# Processing record 6 of set 10 -----> capitao poco
# Processing record 7 of set 10 -----> tommot
# Processing record 8 of set 10 -----> qingquan
# Processing record 9 of set 10 -----> ajdabiya
# Processing record 10 of set 10 -----> tiarei
# Processing record 11 of set 10 -----> masuda
# Processing record 12 of set 10 -----> ondangwa
# Processing record 13 of set 10 -----> plettenberg bay
# Processing record 14 of set 10 -----> mahibadhoo
# Processing record 15 of set 10 -----> saleaula
# City not found. Skipping...
# Processing record 16 of set 10 -----> walvis bay
# Processing record 17 of set 10 -----> kudahuvadhoo
# Processing record 18 of set 10 -----> kruisfontein
# Processing record 19 of set 10 -----> svetlogorsk
# Processing record 20 of set 10 -----> bamnet narong
# Processing record 21 of set 10 -----> mao
# Processing record 22 of set 10 -----> iberia
# Processing record 23 of set 10 -----> the valley
# Processing record 24 of set 10 -----> bilma
# Processing record 25 of set 10 -----> jumla
# Processing record 26 of set 10 -----> wawa
# Processing record 27 of set 10 -----> komsomolskiy
# Processing record 28 of set 10 -----> shakawe
# Processing record 29 of set 10 -----> nyurba
# Processing record 30 of set 10 -----> samarai
# Processing record 31 of set 10 -----> saleilua
# City not found. Skipping...
# Processing record 32 of set 10 -----> half moon bay
# Processing record 33 of set 10 -----> hay river
# Processing record 34 of set 10 -----> havre-saint-pierre
# Processing record 35 of set 10 -----> taltal
# Processing record 36 of set 10 -----> umzimvubu
# City not found. Skipping...
# Processing record 37 of set 10 -----> chaah
# Processing record 38 of set 10 -----> naldurg
# Processing record 39 of set 10 -----> chernyshevskiy
# Processing record 40 of set 10 -----> tual
# Processing record 41 of set 10 -----> iracoubo
# Processing record 42 of set 10 -----> port lincoln
# Processing record 43 of set 10 -----> ewo
# Processing record 44 of set 10 -----> cap malheureux
# Processing record 45 of set 10 -----> sri aman
# Processing record 46 of set 10 -----> padang
# Processing record 47 of set 10 -----> nagorsk
# Processing record 48 of set 10 -----> mayya
# Processing record 49 of set 10 -----> mabaruma
# Processing record 50 of set 10 -----> micheweni
# Processing record 0 of set 11 -----> ugoofaaru
# Processing record 1 of set 11 -----> grande-riviere
# City not found. Skipping...
# Processing record 2 of set 11 -----> khani
# Processing record 3 of set 11 -----> fairbanks
# Processing record 4 of set 11 -----> yarada
# Processing record 5 of set 11 -----> one hundred mile house
# City not found. Skipping...
# Processing record 6 of set 11 -----> mezen
# Processing record 7 of set 11 -----> pangnirtung
# Processing record 8 of set 11 -----> dongsheng
# Processing record 9 of set 11 -----> dauphin
# Processing record 10 of set 11 -----> arlit
# Processing record 11 of set 11 -----> lismore
# Processing record 12 of set 11 -----> maralal
# Processing record 13 of set 11 -----> santa maria
# Processing record 14 of set 11 -----> rossland
# Processing record 15 of set 11 -----> kununurra
# Processing record 16 of set 11 -----> mongu
# Processing record 17 of set 11 -----> bucak
# Processing record 18 of set 11 -----> gaurnadi
# Processing record 19 of set 11 -----> juneau
# Processing record 20 of set 11 -----> nishihara
# Processing record 21 of set 11 -----> nicoya
# Processing record 22 of set 11 -----> yancheng
# Processing record 23 of set 11 -----> inta
# Processing record 24 of set 11 -----> rawson
# Processing record 25 of set 11 -----> marrakesh
# Processing record 26 of set 11 -----> nome
# Processing record 27 of set 11 -----> concepcion del oro
# Processing record 28 of set 11 -----> presidencia roque saenz pena
# Processing record 29 of set 11 -----> yeppoon
# Processing record 30 of set 11 -----> urdzhar
# City not found. Skipping...
# Processing record 31 of set 11 -----> chibombo
# Processing record 32 of set 11 -----> kimbe
# Processing record 33 of set 11 -----> atrauli
# Processing record 34 of set 11 -----> haines junction
# Processing record 35 of set 11 -----> gigmoto
# Processing record 36 of set 11 -----> berlevag
# Processing record 37 of set 11 -----> taitung
# Processing record 38 of set 11 -----> kloulklubed
# Processing record 39 of set 11 -----> buala
# Processing record 40 of set 11 -----> qom
# Processing record 41 of set 11 -----> nouadhibou
# Processing record 42 of set 11 -----> basco
# Processing record 43 of set 11 -----> vadu moldovei
# Processing record 44 of set 11 -----> tabiauea
# City not found. Skipping...
# Processing record 45 of set 11 -----> vaitupu
# City not found. Skipping...
# ---------------------------------------------------------------------------------

# %%
# Create Data Frame
df_prep = {"City": cityxyz, "Cloudiness" : cloudiness, "Country" : country,
           "Date" : date, "Humidity" : humidity, "Temp": temperature, 
           "Lat" : latitude, "Lng" : longitude, "Wind Speed" : windspeed}
dataframe = pd.DataFrame(df_prep)

# %%
dataframe.count()
# Out:
# City          552
# Cloudiness    552
# Country       552
# Date          552
# Humidity      552
# Temp          552
# Lat           552
# Lng           552
# Wind Speed    552
# dtype: int64

# %%
dataframe.head(10)
# Out:
#           City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0     saldanha          89      PT  1569312872        78  58.90  41.42
# 1      mataura          38      NZ  1569312872        87  43.00 -46.19
# 2       barrow           0      AR  1569312873        67  48.10 -38.31
# 3     luderitz           0      NA  1569312873        36  67.54 -26.65
# 4        vaini          75      IN  1569312873        78  78.80  15.34
# 5        sitka           0      US  1569312873        93  69.01  37.17
# 6  port alfred          41      ZA  1569312874        70  64.99 -33.59
# 7        along         100      IN  1569312874        88  60.88  28.17
# 8       hobart          75      AU  1569312807        46  53.60 -42.88
# 9   tombouctou           0      ML  1569312875         8  98.14  16.77
#
#       Lng  Wind Speed
# 0   -6.55        4.16
# 1  168.86       15.01
# 2  -60.23        5.10
# 3   15.16       12.41
# 4   74.49        4.70
# 5  -99.65       11.01
# 6   26.89        7.00
# 7   94.80        4.88
# 8  147.33       11.41
# 9   -3.01        2.68

# %%
#https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python?utm_source=adwords_ppc&utm_campaignid=1565261270&utm_adgroupid=67750485268&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=1t1&utm_creative=332661264371&utm_targetid=aud-299261629574:dsa-473406573835&utm_loc_interest_ms=&utm_loc_physical_ms=9032185&gclid=Cj0KCQjw_absBRD1ARIsAO4_D3ujei8ii4exnm5AoO-GUSrn2FRg9rrVX7OAA7ruNkMoFofVxcL-_ZYaAoHvEALw_wcB#question11
dataframe.to_csv('../Output/citydata.csv', sep='\t', encoding='utf-8')

# %%
plt.scatter(dataframe["Lat"], dataframe["Temp"], marker="o")

plt.title("City Latitude vs. Max Temperature (09/24/2019)")
plt.ylabel("Temperature")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Figures/latvstemp.png")

plt.show()

# %%
plt.scatter(dataframe["Lat"], dataframe["Humidity"], marker="o")

plt.title("City Latitude vs. Humidity (09/24/2019)")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Figures/latvshum.png")

plt.show()

# %%
plt.scatter(dataframe["Lat"], dataframe["Cloudiness"], marker="o")

plt.title("City Latitude vs. Cloudiness (09/24/2019)")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Figures/latvscloud.png")

plt.show()

# %%
plt.scatter(dataframe["Lat"], dataframe["Wind Speed"], marker="o")

plt.title("City Latitude vs. Wind Speed (09/24/2019)")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Figures/latvswind.png")

plt.show()
