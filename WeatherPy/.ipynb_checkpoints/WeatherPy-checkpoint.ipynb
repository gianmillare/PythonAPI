# %%
# Dependencies
import os
import csv
import json
import requests

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pprint import pprint
from apikey import apikey
from citipy import citipy

latrange = (-90, 90)
lngrange = (-180, 180)

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 636

# %%
record = 0
recordset = 0

latitude = []
longitude = []
temperature = []
cloudiness = []
humidity = []
windspeed = []
date = []
cityxyz = []
country = []

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + apikey
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f001ac5c2e40c2622d097358ae09b387'

# %%
query = f"{url}&q={city}"
query
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f001ac5c2e40c2622d097358ae09b387&q=albany'

# %%
response = requests.get(query).json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 42.65, 'lon': -73.75},
#  'dt': 1569311361,
#  'id': 5106834,
#  'main': {'humidity': 88,
#           'pressure': 1007,
#           'temp': 60.66,
#           'temp_max': 64.4,
#           'temp_min': 57},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 3797,
#          'message': 0.0089,
#          'sunrise': 1569321850,
#          'sunset': 1569365402,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 5.82}}

# %%
print('---------------------------------------------------------------------------------')

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + apikey 

for city in cities:
    
    query_url = url + "&q=" + city
    responsejson = requests.get(query_url).json()
    
    if record < 50:
        record = record + 1
    else:
        recordset = recordset + 1
        record = 0

    print('Processing record ' + str(record) + ' of set ' + str(recordset) + ' -----> ' + city)

    try:
        latitude.append(responsejson['coord']['lat'])
        longitude.append(responsejson['coord']['lon'])
        temperature.append(responsejson['main']['temp_max'])
        humidity.append(responsejson['main']['humidity'])
        cloudiness.append(responsejson['clouds']['all'])
        windspeed.append(responsejson['wind']['speed'])
        date.append(responsejson['dt'])
        country.append(responsejson['sys']['country'])
        cityxyz.append(city)

    except:
        print("City not found. Skipping...")
        pass

print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Processing record 1 of set 0 -----> ponta do sol
# Processing record 2 of set 0 -----> rikitea
# Processing record 3 of set 0 -----> qaanaaq
# Processing record 4 of set 0 -----> busselton
# Processing record 5 of set 0 -----> mangai
# Processing record 6 of set 0 -----> hovd
# Processing record 7 of set 0 -----> hermanus
# Processing record 8 of set 0 -----> new norfolk
# Processing record 9 of set 0 -----> hasaki
# Processing record 10 of set 0 -----> muros
# Processing record 11 of set 0 -----> belushya guba
# City not found. Skipping...
# Processing record 12 of set 0 -----> dikson
# Processing record 13 of set 0 -----> oum hadjer
# Processing record 14 of set 0 -----> preobrazheniye
# Processing record 15 of set 0 -----> hailar
# Processing record 16 of set 0 -----> mys shmidta
# City not found. Skipping...
# Processing record 17 of set 0 -----> ushuaia
# Processing record 18 of set 0 -----> nemuro
# Processing record 19 of set 0 -----> grand bank
# Processing record 20 of set 0 -----> hobart
# Processing record 21 of set 0 -----> carnarvon
# Processing record 22 of set 0 -----> mataura
# Processing record 23 of set 0 -----> ileza
# Processing record 24 of set 0 -----> marcona
# City not found. Skipping...
# Processing record 25 of set 0 -----> tunceli
# Processing record 26 of set 0 -----> upernavik
# Processing record 27 of set 0 -----> bluff
# Processing record 28 of set 0 -----> saldanha
# Processing record 29 of set 0 -----> kapaa
# Processing record 30 of set 0 -----> east london
# Processing record 31 of set 0 -----> babanusah
# City not found. Skipping...
# Processing record 32 of set 0 -----> punta arenas
# Processing record 33 of set 0 -----> albany
# Processing record 34 of set 0 -----> half moon bay
# Processing record 35 of set 0 -----> bengkulu
# City not found. Skipping...
# Processing record 36 of set 0 -----> port hedland
# Processing record 37 of set 0 -----> umzimvubu
# City not found. Skipping...
# Processing record 38 of set 0 -----> san vicente
# Processing record 39 of set 0 -----> yellowknife
# Processing record 40 of set 0 -----> jamestown
# Processing record 41 of set 0 -----> kruisfontein
# Processing record 42 of set 0 -----> hamilton
# Processing record 43 of set 0 -----> sitka
# Processing record 44 of set 0 -----> axim
# Processing record 45 of set 0 -----> pisco
# Processing record 46 of set 0 -----> diu
# Processing record 47 of set 0 -----> chokurdakh
# Processing record 48 of set 0 -----> bredasdorp
# Processing record 49 of set 0 -----> yaan
# Processing record 50 of set 0 -----> atuona
# Processing record 0 of set 1 -----> arak
# Processing record 1 of set 1 -----> norman wells
# Processing record 2 of set 1 -----> las vegas
# Processing record 3 of set 1 -----> longyearbyen
# Processing record 4 of set 1 -----> bethel
# Processing record 5 of set 1 -----> vaini
# Processing record 6 of set 1 -----> kavieng
# Processing record 7 of set 1 -----> georgetown
# Processing record 8 of set 1 -----> luganville
# Processing record 9 of set 1 -----> moroni
# Processing record 10 of set 1 -----> saleaula
# City not found. Skipping...
# Processing record 11 of set 1 -----> cherskiy
# Processing record 12 of set 1 -----> kenitra
# Processing record 13 of set 1 -----> cape town
# Processing record 14 of set 1 -----> lebu
# Processing record 15 of set 1 -----> baffa
# Processing record 16 of set 1 -----> yershichi
# Processing record 17 of set 1 -----> souillac
# Processing record 18 of set 1 -----> amderma
# City not found. Skipping...
# Processing record 19 of set 1 -----> castro
# Processing record 20 of set 1 -----> palmer
# Processing record 21 of set 1 -----> ancud
# Processing record 22 of set 1 -----> gat
# Processing record 23 of set 1 -----> port alfred
# Processing record 24 of set 1 -----> greece
# Processing record 25 of set 1 -----> praia da vitoria
# Processing record 26 of set 1 -----> tuktoyaktuk
# Processing record 27 of set 1 -----> takaka
# Processing record 28 of set 1 -----> palabuhanratu
# City not found. Skipping...
# Processing record 29 of set 1 -----> airai
# Processing record 30 of set 1 -----> leningradskiy
# Processing record 31 of set 1 -----> clyde river
# Processing record 32 of set 1 -----> sao joao da barra
# Processing record 33 of set 1 -----> victoria
# Processing record 34 of set 1 -----> vestmannaeyjar
# Processing record 35 of set 1 -----> zhigansk
# Processing record 36 of set 1 -----> kodiak
# Processing record 37 of set 1 -----> shirokiy
# Processing record 38 of set 1 -----> soyo
# Processing record 39 of set 1 -----> dunedin
# Processing record 40 of set 1 -----> barrow
# Processing record 41 of set 1 -----> kieta
# Processing record 42 of set 1 -----> narsaq
# Processing record 43 of set 1 -----> coquimbo
# Processing record 44 of set 1 -----> taolanaro
# City not found. Skipping...
# Processing record 45 of set 1 -----> mahebourg
# Processing record 46 of set 1 -----> inhambane
# Processing record 47 of set 1 -----> chuy
# Processing record 48 of set 1 -----> ahipara
# Processing record 49 of set 1 -----> bambous virieux
# Processing record 50 of set 1 -----> thompson
# Processing record 0 of set 2 -----> hithadhoo
# Processing record 1 of set 2 -----> san patricio
# Processing record 2 of set 2 -----> puerto ayora
# Processing record 3 of set 2 -----> nanchong
# Processing record 4 of set 2 -----> yumen
# Processing record 5 of set 2 -----> codrington
# Processing record 6 of set 2 -----> presidencia roque saenz pena
# Processing record 7 of set 2 -----> zvishavane
# Processing record 8 of set 2 -----> taganak
# Processing record 9 of set 2 -----> necochea
# Processing record 10 of set 2 -----> khasan
# Processing record 11 of set 2 -----> khatanga
# Processing record 12 of set 2 -----> manta
# Processing record 13 of set 2 -----> akranes
# Processing record 14 of set 2 -----> polunochnoye
# Processing record 15 of set 2 -----> quilmana
# Processing record 16 of set 2 -----> isangel
# Processing record 17 of set 2 -----> genhe
# Processing record 18 of set 2 -----> saint george
# Processing record 19 of set 2 -----> calabozo
# Processing record 20 of set 2 -----> lata
# Processing record 21 of set 2 -----> rudnogorsk
# Processing record 22 of set 2 -----> leh
# Processing record 23 of set 2 -----> kyra
# City not found. Skipping...
# Processing record 24 of set 2 -----> kolokani
# Processing record 25 of set 2 -----> butembo
# Processing record 26 of set 2 -----> boende
# Processing record 27 of set 2 -----> galesong
# Processing record 28 of set 2 -----> kjollefjord
# Processing record 29 of set 2 -----> mgandu
# Processing record 30 of set 2 -----> saint-joseph
# Processing record 31 of set 2 -----> talnakh
# Processing record 32 of set 2 -----> acarau
# City not found. Skipping...
# Processing record 33 of set 2 -----> tawkar
# City not found. Skipping...
# Processing record 34 of set 2 -----> lujan
# Processing record 35 of set 2 -----> sedelnikovo
# City not found. Skipping...
# Processing record 36 of set 2 -----> kamenskoye
# City not found. Skipping...
# Processing record 37 of set 2 -----> vardo
# Processing record 38 of set 2 -----> vilhena
# Processing record 39 of set 2 -----> san cristobal
# Processing record 40 of set 2 -----> coolum beach
# Processing record 41 of set 2 -----> nikolskoye
# Processing record 42 of set 2 -----> kristiansund
# Processing record 43 of set 2 -----> alice springs
# Processing record 44 of set 2 -----> alofi
# Processing record 45 of set 2 -----> bababe
# City not found. Skipping...
# Processing record 46 of set 2 -----> los llanos de aridane
# Processing record 47 of set 2 -----> nizhneyansk
# City not found. Skipping...
# Processing record 48 of set 2 -----> sakakah
# City not found. Skipping...
# Processing record 49 of set 2 -----> batagay
# Processing record 50 of set 2 -----> lichinga
# Processing record 0 of set 3 -----> hilo
# Processing record 1 of set 3 -----> illoqqortoormiut
# City not found. Skipping...
# Processing record 2 of set 3 -----> powell
# Processing record 3 of set 3 -----> vila velha
# Processing record 4 of set 3 -----> port elizabeth
# Processing record 5 of set 3 -----> mrirt
# City not found. Skipping...
# Processing record 6 of set 3 -----> vanderhoof
# Processing record 7 of set 3 -----> muskogee
# Processing record 8 of set 3 -----> angoche
# Processing record 9 of set 3 -----> taltal
# Processing record 10 of set 3 -----> herat
# Processing record 11 of set 3 -----> tasiilaq
# Processing record 12 of set 3 -----> catuday
# Processing record 13 of set 3 -----> guadix
# Processing record 14 of set 3 -----> zhongshan
# Processing record 15 of set 3 -----> alihe
# Processing record 16 of set 3 -----> kondagaon
# Processing record 17 of set 3 -----> berdigestyakh
# Processing record 18 of set 3 -----> bosaso
# Processing record 19 of set 3 -----> altay
# Processing record 20 of set 3 -----> asau
# City not found. Skipping...
# Processing record 21 of set 3 -----> muli
# Processing record 22 of set 3 -----> anadyr
# Processing record 23 of set 3 -----> fortuna
# Processing record 24 of set 3 -----> holland
# Processing record 25 of set 3 -----> husavik
# Processing record 26 of set 3 -----> keti bandar
# Processing record 27 of set 3 -----> grand gaube
# Processing record 28 of set 3 -----> avarua
# Processing record 29 of set 3 -----> oksfjord
# Processing record 30 of set 3 -----> bonavista
# Processing record 31 of set 3 -----> trinidad
# Processing record 32 of set 3 -----> san quintin
# Processing record 33 of set 3 -----> cidreira
# Processing record 34 of set 3 -----> pinawa
# Processing record 35 of set 3 -----> poum
# Processing record 36 of set 3 -----> pacific grove
# Processing record 37 of set 3 -----> puerto madryn
# Processing record 38 of set 3 -----> touros
# Processing record 39 of set 3 -----> arraial do cabo
# Processing record 40 of set 3 -----> weyburn
# Processing record 41 of set 3 -----> rock sound
# Processing record 42 of set 3 -----> winslow
# Processing record 43 of set 3 -----> dingzhou
# Processing record 44 of set 3 -----> aflu
# City not found. Skipping...
# Processing record 45 of set 3 -----> forest hills
# Processing record 46 of set 3 -----> chernyshevskiy
# Processing record 47 of set 3 -----> morada nova
# Processing record 48 of set 3 -----> saint-philippe
# Processing record 49 of set 3 -----> chumikan
# Processing record 50 of set 3 -----> oranjemund
# Processing record 0 of set 4 -----> fremont
# Processing record 1 of set 4 -----> nampula
# Processing record 2 of set 4 -----> kennett
# Processing record 3 of set 4 -----> oussouye
# Processing record 4 of set 4 -----> lubao
# Processing record 5 of set 4 -----> koulamoutou
# Processing record 6 of set 4 -----> vila franca do campo
# Processing record 7 of set 4 -----> emba
# Processing record 8 of set 4 -----> pangnirtung
# Processing record 9 of set 4 -----> yirol
# City not found. Skipping...
# Processing record 10 of set 4 -----> grand river south east
# City not found. Skipping...
# Processing record 11 of set 4 -----> lagos
# Processing record 12 of set 4 -----> phalaborwa
# Processing record 13 of set 4 -----> ilulissat
# Processing record 14 of set 4 -----> saint-leu
# Processing record 15 of set 4 -----> barentsburg
# City not found. Skipping...
# Processing record 16 of set 4 -----> severo-kurilsk
# Processing record 17 of set 4 -----> beringovskiy
# Processing record 18 of set 4 -----> kununurra
# Processing record 19 of set 4 -----> abu kamal
# Processing record 20 of set 4 -----> dinsor
# City not found. Skipping...
# Processing record 21 of set 4 -----> kalangala
# Processing record 22 of set 4 -----> attawapiskat
# City not found. Skipping...
# Processing record 23 of set 4 -----> kupang
# Processing record 24 of set 4 -----> antsohihy
# Processing record 25 of set 4 -----> tautira
# Processing record 26 of set 4 -----> nanortalik
# Processing record 27 of set 4 -----> tiksi
# Processing record 28 of set 4 -----> khurianwala
# City not found. Skipping...
# Processing record 29 of set 4 -----> ulaanbaatar
# Processing record 30 of set 4 -----> butaritari
# Processing record 31 of set 4 -----> suicheng
# Processing record 32 of set 4 -----> bartica
# Processing record 33 of set 4 -----> barghat
# Processing record 34 of set 4 -----> shenjiamen
# Processing record 35 of set 4 -----> dingle
# Processing record 36 of set 4 -----> la ronge
# Processing record 37 of set 4 -----> ambilobe
# Processing record 38 of set 4 -----> oranjestad
# Processing record 39 of set 4 -----> vermillion
# Processing record 40 of set 4 -----> kalabo
# Processing record 41 of set 4 -----> ulladulla
# Processing record 42 of set 4 -----> wulanhaote
# City not found. Skipping...
# Processing record 43 of set 4 -----> beloha
# Processing record 44 of set 4 -----> korla
# City not found. Skipping...
# Processing record 45 of set 4 -----> kavaratti
# Processing record 46 of set 4 -----> viligili
# City not found. Skipping...
# Processing record 47 of set 4 -----> talakan
# Processing record 48 of set 4 -----> bendigo
# Processing record 49 of set 4 -----> mar del plata
# Processing record 50 of set 4 -----> tripoli
# Processing record 0 of set 5 -----> dakar
# Processing record 1 of set 5 -----> abha
# Processing record 2 of set 5 -----> taburi
# City not found. Skipping...
# Processing record 3 of set 5 -----> kaupanger
# Processing record 4 of set 5 -----> santa maria
# Processing record 5 of set 5 -----> sataua
# City not found. Skipping...
# Processing record 6 of set 5 -----> ostrovnoy
# Processing record 7 of set 5 -----> grindavik
# Processing record 8 of set 5 -----> kudal
# Processing record 9 of set 5 -----> laguna
# Processing record 10 of set 5 -----> esperance
# Processing record 11 of set 5 -----> bilibino
# Processing record 12 of set 5 -----> arroyo
# Processing record 13 of set 5 -----> iqaluit
# Processing record 14 of set 5 -----> cabo san lucas
# Processing record 15 of set 5 -----> mercedes
# Processing record 16 of set 5 -----> cabedelo
# Processing record 17 of set 5 -----> kingaroy
# Processing record 18 of set 5 -----> majalgaon
# Processing record 19 of set 5 -----> prince rupert
# Processing record 20 of set 5 -----> eydhafushi
# Processing record 21 of set 5 -----> svetlaya
# Processing record 22 of set 5 -----> port lincoln
# Processing record 23 of set 5 -----> onguday
# Processing record 24 of set 5 -----> masvingo
# Processing record 25 of set 5 -----> ciudad bolivar
# Processing record 26 of set 5 -----> banda aceh
# Processing record 27 of set 5 -----> sumbawa
# City not found. Skipping...
# Processing record 28 of set 5 -----> puerto escondido
# Processing record 29 of set 5 -----> kinna
# Processing record 30 of set 5 -----> yelizovo
# Processing record 31 of set 5 -----> tsihombe
# City not found. Skipping...
# Processing record 32 of set 5 -----> caravelas
# Processing record 33 of set 5 -----> fairbanks
# Processing record 34 of set 5 -----> torbay
# Processing record 35 of set 5 -----> egvekinot
# Processing record 36 of set 5 -----> luderitz
# Processing record 37 of set 5 -----> amurzet
# Processing record 38 of set 5 -----> guerrero negro
# Processing record 39 of set 5 -----> west des moines
# Processing record 40 of set 5 -----> agadez
# Processing record 41 of set 5 -----> de aar
# Processing record 42 of set 5 -----> subiaco
# Processing record 43 of set 5 -----> bambanglipuro
# Processing record 44 of set 5 -----> kahului
# Processing record 45 of set 5 -----> severo-yeniseyskiy
# Processing record 46 of set 5 -----> haibowan
# City not found. Skipping...
# Processing record 47 of set 5 -----> salalah
# Processing record 48 of set 5 -----> avera
# Processing record 49 of set 5 -----> portland
# Processing record 50 of set 5 -----> nome
# Processing record 0 of set 6 -----> katsina
# Processing record 1 of set 6 -----> lolua
# City not found. Skipping...
# Processing record 2 of set 6 -----> arlit
# Processing record 3 of set 6 -----> rondonopolis
# Processing record 4 of set 6 -----> jerantut
# Processing record 5 of set 6 -----> santa cruz de la palma
# Processing record 6 of set 6 -----> turukhansk
# Processing record 7 of set 6 -----> asuncion
# Processing record 8 of set 6 -----> zhezkazgan
# Processing record 9 of set 6 -----> kharitonovo
# Processing record 10 of set 6 -----> tumannyy
# City not found. Skipping...
# Processing record 11 of set 6 -----> sisimiut
# Processing record 12 of set 6 -----> berberati
# Processing record 13 of set 6 -----> chicama
# Processing record 14 of set 6 -----> saskylakh
# Processing record 15 of set 6 -----> talaya
# Processing record 16 of set 6 -----> jinchang
# Processing record 17 of set 6 -----> nizhniy baskunchak
# Processing record 18 of set 6 -----> malartic
# Processing record 19 of set 6 -----> marsh harbour
# Processing record 20 of set 6 -----> storsteinnes
# Processing record 21 of set 6 -----> port-gentil
# Processing record 22 of set 6 -----> baghdad
# Processing record 23 of set 6 -----> soligalich
# Processing record 24 of set 6 -----> antalaha
# Processing record 25 of set 6 -----> chikwawa
# Processing record 26 of set 6 -----> cayenne
# Processing record 27 of set 6 -----> tateyama
# Processing record 28 of set 6 -----> shemgang
# Processing record 29 of set 6 -----> chamba
# Processing record 30 of set 6 -----> samusu
# City not found. Skipping...
# Processing record 31 of set 6 -----> temiscaming
# Processing record 32 of set 6 -----> umm lajj
# Processing record 33 of set 6 -----> belle fourche
# Processing record 34 of set 6 -----> thano bula khan
# City not found. Skipping...
# Processing record 35 of set 6 -----> piacabucu
# Processing record 36 of set 6 -----> son la
# Processing record 37 of set 6 -----> jarjis
# City not found. Skipping...
# Processing record 38 of set 6 -----> natchez
# Processing record 39 of set 6 -----> kifri
# Processing record 40 of set 6 -----> novikovo
# Processing record 41 of set 6 -----> fort nelson
# Processing record 42 of set 6 -----> sao geraldo do araguaia
# Processing record 43 of set 6 -----> tarakan
# Processing record 44 of set 6 -----> tuatapere
# Processing record 45 of set 6 -----> naron
# Processing record 46 of set 6 -----> azoyu
# Processing record 47 of set 6 -----> sentyabrskiy
# City not found. Skipping...
# Processing record 48 of set 6 -----> namibe
# Processing record 49 of set 6 -----> comodoro rivadavia
# Processing record 50 of set 6 -----> trairi
# Processing record 0 of set 7 -----> bluefield
# Processing record 1 of set 7 -----> swan hill
# Processing record 2 of set 7 -----> faanui
# Processing record 3 of set 7 -----> suntar
# Processing record 4 of set 7 -----> sidi ali
# Processing record 5 of set 7 -----> voi
# Processing record 6 of set 7 -----> pevek
# Processing record 7 of set 7 -----> mayo
# Processing record 8 of set 7 -----> mantua
# Processing record 9 of set 7 -----> namatanai
# Processing record 10 of set 7 -----> tamiahua
# Processing record 11 of set 7 -----> nabire
# Processing record 12 of set 7 -----> svetlogorsk
# Processing record 13 of set 7 -----> kudahuvadhoo
# Processing record 14 of set 7 -----> buritizeiro
# Processing record 15 of set 7 -----> karaton
# Processing record 16 of set 7 -----> kawalu
# Processing record 17 of set 7 -----> marzuq
# Processing record 18 of set 7 -----> wajir
# Processing record 19 of set 7 -----> kampong chhnang
# Processing record 20 of set 7 -----> yatou
# Processing record 21 of set 7 -----> lavrentiya
# Processing record 22 of set 7 -----> ibra
# Processing record 23 of set 7 -----> hervey bay
# Processing record 24 of set 7 -----> itoman
# Processing record 25 of set 7 -----> xudat
# Processing record 26 of set 7 -----> kitimat
# Processing record 27 of set 7 -----> qaqortoq
# Processing record 28 of set 7 -----> visnes
# Processing record 29 of set 7 -----> daru
# Processing record 30 of set 7 -----> ilhabela
# Processing record 31 of set 7 -----> flin flon
# Processing record 32 of set 7 -----> fethiye
# Processing record 33 of set 7 -----> nara
# Processing record 34 of set 7 -----> menongue
# Processing record 35 of set 7 -----> north bend
# Processing record 36 of set 7 -----> geraldton
# Processing record 37 of set 7 -----> tarudant
# City not found. Skipping...
# Processing record 38 of set 7 -----> sosva
# Processing record 39 of set 7 -----> marsabit
# Processing record 40 of set 7 -----> satitoa
# City not found. Skipping...
# Processing record 41 of set 7 -----> kaeo
# Processing record 42 of set 7 -----> innisfail
# Processing record 43 of set 7 -----> balaghat
# Processing record 44 of set 7 -----> saint marys
# Processing record 45 of set 7 -----> xingyi
# Processing record 46 of set 7 -----> claudio
# Processing record 47 of set 7 -----> provideniya
# Processing record 48 of set 7 -----> karratha
# Processing record 49 of set 7 -----> lazarev
# Processing record 50 of set 7 -----> la macarena
# Processing record 0 of set 8 -----> boysun
# Processing record 1 of set 8 -----> ji-parana
# City not found. Skipping...
# Processing record 2 of set 8 -----> pasighat
# Processing record 3 of set 8 -----> kota kinabalu
# Processing record 4 of set 8 -----> strezhevoy
# Processing record 5 of set 8 -----> teodoro sampaio
# Processing record 6 of set 8 -----> san jose
# Processing record 7 of set 8 -----> nantucket
# Processing record 8 of set 8 -----> hambantota
# Processing record 9 of set 8 -----> sao filipe
# Processing record 10 of set 8 -----> klaksvik
# Processing record 11 of set 8 -----> tuytepa
# Processing record 12 of set 8 -----> mount pleasant
# Processing record 13 of set 8 -----> nijar
# Processing record 14 of set 8 -----> richards bay
# Processing record 15 of set 8 -----> khuzdar
# Processing record 16 of set 8 -----> duluth
# Processing record 17 of set 8 -----> paamiut
# Processing record 18 of set 8 -----> ribeira grande
# Processing record 19 of set 8 -----> honggang
# Processing record 20 of set 8 -----> artesia
# Processing record 21 of set 8 -----> maniitsoq
# Processing record 22 of set 8 -----> gramsh
# Processing record 23 of set 8 -----> garwolin
# Processing record 24 of set 8 -----> kibondo
# Processing record 25 of set 8 -----> palmas
# Processing record 26 of set 8 -----> sola
# Processing record 27 of set 8 -----> praia
# Processing record 28 of set 8 -----> tromso
# Processing record 29 of set 8 -----> beyneu
# Processing record 30 of set 8 -----> makakilo city
# Processing record 31 of set 8 -----> hofn
# Processing record 32 of set 8 -----> tapanatepec
# City not found. Skipping...
# Processing record 33 of set 8 -----> south river
# Processing record 34 of set 8 -----> wuwei
# Processing record 35 of set 8 -----> laredo
# Processing record 36 of set 8 -----> finnsnes
# Processing record 37 of set 8 -----> verkhoyansk
# Processing record 38 of set 8 -----> lakatoro
# Processing record 39 of set 8 -----> kaitangata
# Processing record 40 of set 8 -----> lagoa
# Processing record 41 of set 8 -----> margate
# Processing record 42 of set 8 -----> unity
# Processing record 43 of set 8 -----> tiznit
# Processing record 44 of set 8 -----> coutances
# Processing record 45 of set 8 -----> popondetta
# Processing record 46 of set 8 -----> burnie
# Processing record 47 of set 8 -----> toora-khem
# Processing record 48 of set 8 -----> adrar
# Processing record 49 of set 8 -----> rochegda
# Processing record 50 of set 8 -----> cairns
# Processing record 0 of set 9 -----> bellevue
# Processing record 1 of set 9 -----> viedma
# Processing record 2 of set 9 -----> skagastrond
# City not found. Skipping...
# Processing record 3 of set 9 -----> ballina
# Processing record 4 of set 9 -----> mayumba
# Processing record 5 of set 9 -----> laurel
# Processing record 6 of set 9 -----> atar
# Processing record 7 of set 9 -----> filingue
# Processing record 8 of set 9 -----> hede
# Processing record 9 of set 9 -----> deputatskiy
# Processing record 10 of set 9 -----> saint helens
# Processing record 11 of set 9 -----> vancouver
# Processing record 12 of set 9 -----> andra
# Processing record 13 of set 9 -----> merauke
# Processing record 14 of set 9 -----> hwange
# Processing record 15 of set 9 -----> lerwick
# Processing record 16 of set 9 -----> vostochnyy
# Processing record 17 of set 9 -----> mbigou
# Processing record 18 of set 9 -----> maarianhamina
# City not found. Skipping...
# Processing record 19 of set 9 -----> barra do garcas
# Processing record 20 of set 9 -----> lasa
# Processing record 21 of set 9 -----> neenah
# Processing record 22 of set 9 -----> kastamonu
# Processing record 23 of set 9 -----> lethem
# Processing record 24 of set 9 -----> olavarria
# Processing record 25 of set 9 -----> tambopata
# City not found. Skipping...
# Processing record 26 of set 9 -----> sioux lookout
# Processing record 27 of set 9 -----> coos bay
# Processing record 28 of set 9 -----> butiama
# Processing record 29 of set 9 -----> bozova
# Processing record 30 of set 9 -----> emerald
# Processing record 31 of set 9 -----> grand centre
# City not found. Skipping...
# Processing record 32 of set 9 -----> atherton
# Processing record 33 of set 9 -----> kilindoni
# Processing record 34 of set 9 -----> phangnga
# Processing record 35 of set 9 -----> san juan
# Processing record 36 of set 9 -----> haines junction
# Processing record 37 of set 9 -----> clyde
# Processing record 38 of set 9 -----> manavalakurichi
# Processing record 39 of set 9 -----> constitucion
# Processing record 40 of set 9 -----> belaya gora
# Processing record 41 of set 9 -----> mitu
# Processing record 42 of set 9 -----> bilma
# Processing record 43 of set 9 -----> bulungu
# Processing record 44 of set 9 -----> batemans bay
# Processing record 45 of set 9 -----> paso de los toros
# Processing record 46 of set 9 -----> komsomolskiy
# Processing record 47 of set 9 -----> sorvag
# City not found. Skipping...
# Processing record 48 of set 9 -----> dzhusaly
# City not found. Skipping...
# Processing record 49 of set 9 -----> guiratinga
# Processing record 50 of set 9 -----> okhotsk
# Processing record 0 of set 10 -----> mnogovershinnyy
# Processing record 1 of set 10 -----> quang ngai
# Processing record 2 of set 10 -----> wuda
# Processing record 3 of set 10 -----> padang
# Processing record 4 of set 10 -----> port moresby
# Processing record 5 of set 10 -----> kyabe
# Processing record 6 of set 10 -----> garowe
# Processing record 7 of set 10 -----> jalu
# Processing record 8 of set 10 -----> maroua
# Processing record 9 of set 10 -----> samarai
# Processing record 10 of set 10 -----> bargal
# City not found. Skipping...
# Processing record 11 of set 10 -----> novovasylivka
# Processing record 12 of set 10 -----> pokrovsk-uralskiy
# City not found. Skipping...
# Processing record 13 of set 10 -----> broken hill
# Processing record 14 of set 10 -----> novovarshavka
# Processing record 15 of set 10 -----> alashtar
# City not found. Skipping...
# Processing record 16 of set 10 -----> rocky mountain house
# Processing record 17 of set 10 -----> praya
# Processing record 18 of set 10 -----> ngukurr
# City not found. Skipping...
# Processing record 19 of set 10 -----> progreso
# Processing record 20 of set 10 -----> labuhan
# Processing record 21 of set 10 -----> rio claro
# Processing record 22 of set 10 -----> ahuimanu
# Processing record 23 of set 10 -----> penco
# Processing record 24 of set 10 -----> puksoozero
# Processing record 25 of set 10 -----> flers
# Processing record 26 of set 10 -----> barmer
# Processing record 27 of set 10 -----> svetlyy
# City not found. Skipping...
# Processing record 28 of set 10 -----> gamba
# Processing record 29 of set 10 -----> zatoka
# Processing record 30 of set 10 -----> trincomalee
# Processing record 31 of set 10 -----> palmerston
# Processing record 32 of set 10 -----> alamos
# Processing record 33 of set 10 -----> hobbs
# Processing record 34 of set 10 -----> santona
# Processing record 35 of set 10 -----> ulaangom
# Processing record 36 of set 10 -----> barbar
# City not found. Skipping...
# Processing record 37 of set 10 -----> kuryk
# Processing record 38 of set 10 -----> guaymas
# Processing record 39 of set 10 -----> constantine
# Processing record 40 of set 10 -----> chopinzinho
# Processing record 41 of set 10 -----> mandali
# Processing record 42 of set 10 -----> weligama
# Processing record 43 of set 10 -----> westport
# Processing record 44 of set 10 -----> boa viagem
# Processing record 45 of set 10 -----> jacareacanga
# Processing record 46 of set 10 -----> porto novo
# Processing record 47 of set 10 -----> nevelsk
# Processing record 48 of set 10 -----> bathsheba
# Processing record 49 of set 10 -----> hemsedal
# Processing record 50 of set 10 -----> lahaina
# Processing record 0 of set 11 -----> soe
# Processing record 1 of set 11 -----> otavalo
# Processing record 2 of set 11 -----> opuwo
# Processing record 3 of set 11 -----> walcourt
# Processing record 4 of set 11 -----> smithers
# Processing record 5 of set 11 -----> arilje
# Processing record 6 of set 11 -----> mitsamiouli
# Processing record 7 of set 11 -----> biloela
# Processing record 8 of set 11 -----> haapiti
# Processing record 9 of set 11 -----> bandarbeyla
# Processing record 10 of set 11 -----> codajas
# Processing record 11 of set 11 -----> kysyl-syr
# Processing record 12 of set 11 -----> yar-sale
# Processing record 13 of set 11 -----> murgab
# Processing record 14 of set 11 -----> zolotinka
# City not found. Skipping...
# Processing record 15 of set 11 -----> vilcun
# Processing record 16 of set 11 -----> cockburn town
# Processing record 17 of set 11 -----> do gonbadan
# Processing record 18 of set 11 -----> fernley
# Processing record 19 of set 11 -----> skrunda
# Processing record 20 of set 11 -----> yantal
# Processing record 21 of set 11 -----> balikpapan
# Processing record 22 of set 11 -----> kiruna
# Processing record 23 of set 11 -----> helong
# Processing record 24 of set 11 -----> port hardy
# Processing record 25 of set 11 -----> arsenyev
# Processing record 26 of set 11 -----> galle
# Processing record 27 of set 11 -----> raga
# City not found. Skipping...
# Processing record 28 of set 11 -----> ust-kuyga
# Processing record 29 of set 11 -----> santa rosa
# Processing record 30 of set 11 -----> general roca
# Processing record 31 of set 11 -----> mtsensk
# Processing record 32 of set 11 -----> camacari
# Processing record 33 of set 11 -----> karpinsk
# Processing record 34 of set 11 -----> magui
# City not found. Skipping...
# Processing record 35 of set 11 -----> mount isa
# Processing record 36 of set 11 -----> fevralsk
# City not found. Skipping...
# Processing record 37 of set 11 -----> wladyslawowo
# Processing record 38 of set 11 -----> rodrigues alves
# Processing record 39 of set 11 -----> celestun
# Processing record 40 of set 11 -----> merrill
# Processing record 41 of set 11 -----> nyurba
# Processing record 42 of set 11 -----> disraeli
# Processing record 43 of set 11 -----> williams lake
# Processing record 44 of set 11 -----> luxor
# Processing record 45 of set 11 -----> ayagoz
# Processing record 46 of set 11 -----> hami
# Processing record 47 of set 11 -----> eureka
# Processing record 48 of set 11 -----> nerja
# Processing record 49 of set 11 -----> bireun
# Processing record 50 of set 11 -----> kermanshah
# Processing record 0 of set 12 -----> lorengau
# Processing record 1 of set 12 -----> omaruru
# Processing record 2 of set 12 -----> yulara
# Processing record 3 of set 12 -----> harnosand
# Processing record 4 of set 12 -----> krupina
# Processing record 5 of set 12 -----> kusk
# City not found. Skipping...
# Processing record 6 of set 12 -----> chapais
# Processing record 7 of set 12 -----> olafsvik
# City not found. Skipping...
# Processing record 8 of set 12 -----> cirebon
# Processing record 9 of set 12 -----> turquel
# Processing record 10 of set 12 -----> daliao
# Processing record 11 of set 12 -----> bubaque
# Processing record 12 of set 12 -----> bafq
# Processing record 13 of set 12 -----> srednekolymsk
# Processing record 14 of set 12 -----> coari
# Processing record 15 of set 12 -----> sao miguel do araguaia
# Processing record 16 of set 12 -----> capaci
# Processing record 17 of set 12 -----> marienburg
# Processing record 18 of set 12 -----> riaba
# City not found. Skipping...
# Processing record 19 of set 12 -----> la rioja
# Processing record 20 of set 12 -----> barcelos
# Processing record 21 of set 12 -----> mundra
# Processing record 22 of set 12 -----> puro
# Processing record 23 of set 12 -----> chibuto
# Processing record 24 of set 12 -----> college
# ---------------------------------------------------------------------------------

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
df_prep = {"City": cityxyz, "Cloudiness" : cloudiness, "Country" : country,
           "Date" : date, "Humidity" : humidity, "Temp": temperature, 
           "Lat" : latitude, "Lng" : longitude, "Wind Speed" : windspeed}
dataframe = pd.DataFrame(df_prep)

# %%
dataframe.count()
# Out:
# City          571
# Cloudiness    571
# Country       571
# Date          571
# Humidity      571
# Temp          571
# Lat           571
# Lng           571
# Wind Speed    571
# dtype: int64

# %%
dataframe.head(10)
# Out:
#            City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0  ponta do sol          43      BR  1569311655        79  56.74 -20.63
# 1       rikitea         100      PF  1569311655        72  69.70 -23.12
# 2       qaanaaq         100      GL  1569311655        94  22.36  77.48
# 3     busselton           1      AU  1569311655        40  73.00 -33.64
# 4        mangai          39      CD  1569311656        52  90.40  -4.07
# 5          hovd           0      NO  1569311656        87  52.00  63.83
# 6      hermanus          41      ZA  1569311656        90  71.01 -34.42
# 7   new norfolk          75      AU  1569311657        46  53.60 -42.78
# 8        hasaki          75      JP  1569311657        78  77.00  35.73
# 9         muros          40      ES  1569311657        93  66.00  42.77
#
#       Lng  Wind Speed
# 0  -46.00        6.17
# 1 -134.97       12.33
# 2  -69.36        4.72
# 3  115.35        9.28
# 4   19.59        4.50
# 5   10.70        8.05
# 6   19.24        5.99
# 7  147.06       11.41
# 8  140.83        5.82
# 9   -9.06        5.82

# %%
#https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python?utm_source=adwords_ppc&utm_campaignid=1565261270&utm_adgroupid=67750485268&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=1t1&utm_creative=332661264371&utm_targetid=aud-299261629574:dsa-473406573835&utm_loc_interest_ms=&utm_loc_physical_ms=9032185&gclid=Cj0KCQjw_absBRD1ARIsAO4_D3ujei8ii4exnm5AoO-GUSrn2FRg9rrVX7OAA7ruNkMoFofVxcL-_ZYaAoHvEALw_wcB#question11
dataframe.to_csv('../Output/citydata.csv', sep='\t', encoding='utf-8')

# %%
plt.scatter(dataframe["Lat"], dataframe["Temp"], marker="o")

plt.title("City Latitude vs. Max Temperature (09/24/2019)")
plt.ylabel("Temperature")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Figures/latvstemp.png")

plt.show()

# %%
plt.scatter(dataframe["Lat"], dataframe["Humidity"], marker="o")

plt.title("City Latitude vs. Humidity (09/24/2019)")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Figures/latvshum.png")

plt.show()

# %%
plt.scatter(dataframe["Lat"], dataframe["Cloudiness"], marker="o")

plt.title("City Latitude vs. Cloudiness (09/24/2019)")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Figures/latvscloud.png")

plt.show()

# %%
plt.scatter(dataframe["Lat"], dataframe["Wind Speed"], marker="o")

plt.title("City Latitude vs. Wind Speed (09/24/2019)")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("../Figures/latvswind.png")

plt.show()
