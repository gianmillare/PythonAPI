# %%
# Dependencies
import os
import csv
import json
import requests

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pprint import pprint
from apikey import apikey
from citipy import citipy

latrange = (-90, 90)
lngrange = (-180, 180)

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 594

# %%
record = 0
recordset = 0

latitude = []
longitude = []
temperature = []
cloudiness = []
humidity = []
windspeed = []
date = []
cityxyz = []
country = []

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + apikey
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f001ac5c2e40c2622d097358ae09b387'

# %%
query = f"{url}&q={city}"
query
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f001ac5c2e40c2622d097358ae09b387&q=punta arenas'

# %%
response = requests.get(query).json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -53.16, 'lon': -70.91},
#  'dt': 1569310684,
#  'id': 3874787,
#  'main': {'humidity': 76,
#           'pressure': 997,
#           'temp': 48.09,
#           'temp_max': 48.2,
#           'temp_min': 48},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'message': 0.0061,
#          'sunrise': 1569320875,
#          'sunset': 1569365014,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'speed': 28.86}}

# %%
print('---------------------------------------------------------------------------------')

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + apikey 

for city in cities:
    
    query_url = url + "&q=" + city
    responsejson = requests.get(query_url).json()
    
    if record < 50:
        record = record + 1
    else:
        recordset = recordset + 1
        record = 0

    print('Processing record ' + str(record) + ' of set ' + str(recordset) + ' -----> ' + city)

    try:
        latitude.append(responsejson['coord']['lat'])
        longitude.append(responsejson['coord']['lon'])
        temperature.append(responsejson['main']['temp_max'])
        humidity.append(responsejson['main']['humidity'])
        cloudiness.append(responsejson['clouds']['all'])
        windspeed.append(responsejson['wind']['speed'])
        date.append(responsejson['dt'])
        country.append(responsejson['sys']['country'])
        cityxyz.append(city)

    except:
        print("City not found. Skipping...")
        pass

print('---------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------
# Processing record 1 of set 0 -----> hamilton
# Processing record 2 of set 0 -----> busselton
# Processing record 3 of set 0 -----> rikitea
# Processing record 4 of set 0 -----> roma
# Processing record 5 of set 0 -----> jamestown
# Processing record 6 of set 0 -----> sitka
# Processing record 7 of set 0 -----> pacific grove
# Processing record 8 of set 0 -----> sabang
# Processing record 9 of set 0 -----> sibolga
# Processing record 10 of set 0 -----> launceston
# Processing record 11 of set 0 -----> vanderhoof
# Processing record 12 of set 0 -----> nome
# Processing record 13 of set 0 -----> charters towers
# Processing record 14 of set 0 -----> vila
# Processing record 15 of set 0 -----> punta arenas
# Processing record 16 of set 0 -----> pimentel
# Processing record 17 of set 0 -----> hvammstangi
# City not found. Skipping...
# Processing record 18 of set 0 -----> mahebourg
# Processing record 19 of set 0 -----> richards bay
# Processing record 20 of set 0 -----> saint-philippe
# Processing record 21 of set 0 -----> dano
# Processing record 22 of set 0 -----> cabo san lucas
# Processing record 23 of set 0 -----> hualmay
# Processing record 24 of set 0 -----> mar del plata
# Processing record 25 of set 0 -----> avarua
# Processing record 26 of set 0 -----> clyde river
# Processing record 27 of set 0 -----> los llanos de aridane
# Processing record 28 of set 0 -----> wanning
# Processing record 29 of set 0 -----> bertoua
# Processing record 30 of set 0 -----> norman wells
# Processing record 31 of set 0 -----> severo-kurilsk
# Processing record 32 of set 0 -----> brae
# Processing record 33 of set 0 -----> saint-leu
# Processing record 34 of set 0 -----> benton
# Processing record 35 of set 0 -----> ushuaia
# Processing record 36 of set 0 -----> port alfred
# Processing record 37 of set 0 -----> hermanus
# Processing record 38 of set 0 -----> kaitangata
# Processing record 39 of set 0 -----> zadonsk
# Processing record 40 of set 0 -----> taolanaro
# City not found. Skipping...
# Processing record 41 of set 0 -----> cape town
# Processing record 42 of set 0 -----> tuktoyaktuk
# Processing record 43 of set 0 -----> faanui
# Processing record 44 of set 0 -----> puerto ayora
# Processing record 45 of set 0 -----> porto novo
# Processing record 46 of set 0 -----> parana
# Processing record 47 of set 0 -----> yellowknife
# Processing record 48 of set 0 -----> kalmunai
# Processing record 49 of set 0 -----> plastun
# Processing record 50 of set 0 -----> saldanha
# Processing record 0 of set 1 -----> tiksi
# Processing record 1 of set 1 -----> klaksvik
# Processing record 2 of set 1 -----> kushima
# Processing record 3 of set 1 -----> vaini
# Processing record 4 of set 1 -----> gwadar
# Processing record 5 of set 1 -----> albany
# Processing record 6 of set 1 -----> tibati
# Processing record 7 of set 1 -----> pitimbu
# Processing record 8 of set 1 -----> fortuna
# Processing record 9 of set 1 -----> kerema
# Processing record 10 of set 1 -----> tsihombe
# City not found. Skipping...
# Processing record 11 of set 1 -----> tutla
# City not found. Skipping...
# Processing record 12 of set 1 -----> manaure
# Processing record 13 of set 1 -----> hithadhoo
# Processing record 14 of set 1 -----> butaritari
# Processing record 15 of set 1 -----> jasper
# Processing record 16 of set 1 -----> lebu
# Processing record 17 of set 1 -----> belushya guba
# City not found. Skipping...
# Processing record 18 of set 1 -----> tsiroanomandidy
# Processing record 19 of set 1 -----> ponta do sol
# Processing record 20 of set 1 -----> xining
# Processing record 21 of set 1 -----> georgetown
# Processing record 22 of set 1 -----> nikita
# Processing record 23 of set 1 -----> deputatskiy
# Processing record 24 of set 1 -----> castro
# Processing record 25 of set 1 -----> riom
# Processing record 26 of set 1 -----> greenwood
# Processing record 27 of set 1 -----> bonavista
# Processing record 28 of set 1 -----> darhan
# Processing record 29 of set 1 -----> thompson
# Processing record 30 of set 1 -----> rio gallegos
# Processing record 31 of set 1 -----> pottstown
# Processing record 32 of set 1 -----> sioux lookout
# Processing record 33 of set 1 -----> codrington
# Processing record 34 of set 1 -----> ilulissat
# Processing record 35 of set 1 -----> manjo
# Processing record 36 of set 1 -----> san bernardo
# Processing record 37 of set 1 -----> saint-ambroise
# Processing record 38 of set 1 -----> cabedelo
# Processing record 39 of set 1 -----> umzimvubu
# City not found. Skipping...
# Processing record 40 of set 1 -----> lagoa
# Processing record 41 of set 1 -----> bethel
# Processing record 42 of set 1 -----> dikson
# Processing record 43 of set 1 -----> padang
# Processing record 44 of set 1 -----> dharampuri
# Processing record 45 of set 1 -----> coroico
# Processing record 46 of set 1 -----> saleaula
# City not found. Skipping...
# Processing record 47 of set 1 -----> hami
# Processing record 48 of set 1 -----> kodiak
# Processing record 49 of set 1 -----> mataura
# Processing record 50 of set 1 -----> oulu
# Processing record 0 of set 2 -----> bluff
# Processing record 1 of set 2 -----> qaanaaq
# Processing record 2 of set 2 -----> rafaela
# Processing record 3 of set 2 -----> lorengau
# Processing record 4 of set 2 -----> nova olimpia
# Processing record 5 of set 2 -----> petrovsk-zabaykalskiy
# Processing record 6 of set 2 -----> amderma
# City not found. Skipping...
# Processing record 7 of set 2 -----> muros
# Processing record 8 of set 2 -----> atuona
# Processing record 9 of set 2 -----> katsuura
# Processing record 10 of set 2 -----> loa janan
# Processing record 11 of set 2 -----> new norfolk
# Processing record 12 of set 2 -----> cherskiy
# Processing record 13 of set 2 -----> arraial do cabo
# Processing record 14 of set 2 -----> hilo
# Processing record 15 of set 2 -----> khatanga
# Processing record 16 of set 2 -----> tevaitoa
# Processing record 17 of set 2 -----> hobyo
# Processing record 18 of set 2 -----> palabuhanratu
# City not found. Skipping...
# Processing record 19 of set 2 -----> wattegama
# Processing record 20 of set 2 -----> ulaanbaatar
# Processing record 21 of set 2 -----> hobart
# Processing record 22 of set 2 -----> east london
# Processing record 23 of set 2 -----> barentsburg
# City not found. Skipping...
# Processing record 24 of set 2 -----> cayenne
# Processing record 25 of set 2 -----> senanga
# Processing record 26 of set 2 -----> ponto novo
# Processing record 27 of set 2 -----> bengkulu
# City not found. Skipping...
# Processing record 28 of set 2 -----> makakilo city
# Processing record 29 of set 2 -----> nikolskoye
# Processing record 30 of set 2 -----> mount gambier
# Processing record 31 of set 2 -----> quatre cocos
# Processing record 32 of set 2 -----> upernavik
# Processing record 33 of set 2 -----> vaitupu
# City not found. Skipping...
# Processing record 34 of set 2 -----> port blair
# Processing record 35 of set 2 -----> kapaa
# Processing record 36 of set 2 -----> roald
# Processing record 37 of set 2 -----> tura
# Processing record 38 of set 2 -----> ribeira grande
# Processing record 39 of set 2 -----> antsirabe
# Processing record 40 of set 2 -----> cidreira
# Processing record 41 of set 2 -----> lata
# Processing record 42 of set 2 -----> chuy
# Processing record 43 of set 2 -----> faya
# Processing record 44 of set 2 -----> yulara
# Processing record 45 of set 2 -----> shache
# Processing record 46 of set 2 -----> natal
# Processing record 47 of set 2 -----> west wendover
# Processing record 48 of set 2 -----> nieuw amsterdam
# Processing record 49 of set 2 -----> riyadh
# Processing record 50 of set 2 -----> nesbyen
# Processing record 0 of set 3 -----> kavieng
# Processing record 1 of set 3 -----> bandarbeyla
# Processing record 2 of set 3 -----> rameswaram
# Processing record 3 of set 3 -----> almaznyy
# Processing record 4 of set 3 -----> birjand
# Processing record 5 of set 3 -----> markova
# Processing record 6 of set 3 -----> jalu
# Processing record 7 of set 3 -----> torbay
# Processing record 8 of set 3 -----> constitucion
# Processing record 9 of set 3 -----> khandyga
# Processing record 10 of set 3 -----> uige
# Processing record 11 of set 3 -----> kaeo
# Processing record 12 of set 3 -----> chokurdakh
# Processing record 13 of set 3 -----> umm lajj
# Processing record 14 of set 3 -----> porto velho
# Processing record 15 of set 3 -----> savyntsi
# Processing record 16 of set 3 -----> gudibanda
# Processing record 17 of set 3 -----> honningsvag
# Processing record 18 of set 3 -----> saint-gilles
# Processing record 19 of set 3 -----> qaqortoq
# Processing record 20 of set 3 -----> fairbanks
# Processing record 21 of set 3 -----> itarema
# Processing record 22 of set 3 -----> teknaf
# Processing record 23 of set 3 -----> sinnamary
# Processing record 24 of set 3 -----> bambous virieux
# Processing record 25 of set 3 -----> sabya
# Processing record 26 of set 3 -----> hay river
# Processing record 27 of set 3 -----> clovis
# Processing record 28 of set 3 -----> maldonado
# Processing record 29 of set 3 -----> victor harbor
# Processing record 30 of set 3 -----> eisenberg
# Processing record 31 of set 3 -----> broome
# Processing record 32 of set 3 -----> chumikan
# Processing record 33 of set 3 -----> pevek
# Processing record 34 of set 3 -----> sydney mines
# Processing record 35 of set 3 -----> grand river south east
# City not found. Skipping...
# Processing record 36 of set 3 -----> senno
# Processing record 37 of set 3 -----> broken hill
# Processing record 38 of set 3 -----> sur
# Processing record 39 of set 3 -----> north bend
# Processing record 40 of set 3 -----> marawi
# Processing record 41 of set 3 -----> fare
# Processing record 42 of set 3 -----> bredasdorp
# Processing record 43 of set 3 -----> beloha
# Processing record 44 of set 3 -----> sambava
# Processing record 45 of set 3 -----> acapulco
# Processing record 46 of set 3 -----> moron
# Processing record 47 of set 3 -----> pasni
# Processing record 48 of set 3 -----> komsomolskiy
# Processing record 49 of set 3 -----> gizo
# Processing record 50 of set 3 -----> kadaura
# Processing record 0 of set 4 -----> cockburn town
# Processing record 1 of set 4 -----> lumeje
# Processing record 2 of set 4 -----> illoqqortoormiut
# City not found. Skipping...
# Processing record 3 of set 4 -----> kahului
# Processing record 4 of set 4 -----> lieksa
# Processing record 5 of set 4 -----> carlyle
# Processing record 6 of set 4 -----> chongoyape
# Processing record 7 of set 4 -----> ouesso
# Processing record 8 of set 4 -----> zharkent
# Processing record 9 of set 4 -----> sinop
# Processing record 10 of set 4 -----> yaan
# Processing record 11 of set 4 -----> sumbe
# Processing record 12 of set 4 -----> krasnoselkup
# City not found. Skipping...
# Processing record 13 of set 4 -----> misratah
# Processing record 14 of set 4 -----> ostrovnoy
# Processing record 15 of set 4 -----> maragogi
# Processing record 16 of set 4 -----> sentyabrskiy
# City not found. Skipping...
# Processing record 17 of set 4 -----> gorontalo
# Processing record 18 of set 4 -----> batagay-alyta
# Processing record 19 of set 4 -----> barrow
# Processing record 20 of set 4 -----> maruoka
# Processing record 21 of set 4 -----> san roque
# Processing record 22 of set 4 -----> skiros
# City not found. Skipping...
# Processing record 23 of set 4 -----> sibu
# Processing record 24 of set 4 -----> pitea
# Processing record 25 of set 4 -----> khonsa
# Processing record 26 of set 4 -----> saskylakh
# Processing record 27 of set 4 -----> bambanglipuro
# Processing record 28 of set 4 -----> siocon
# Processing record 29 of set 4 -----> carberry
# Processing record 30 of set 4 -----> yar-sale
# Processing record 31 of set 4 -----> cao bang
# Processing record 32 of set 4 -----> luderitz
# Processing record 33 of set 4 -----> conakry
# Processing record 34 of set 4 -----> tuggurt
# City not found. Skipping...
# Processing record 35 of set 4 -----> tommot
# Processing record 36 of set 4 -----> carnarvon
# Processing record 37 of set 4 -----> palauig
# Processing record 38 of set 4 -----> san patricio
# Processing record 39 of set 4 -----> tuatapere
# Processing record 40 of set 4 -----> provideniya
# Processing record 41 of set 4 -----> coquimbo
# Processing record 42 of set 4 -----> jinchengjiang
# City not found. Skipping...
# Processing record 43 of set 4 -----> gat
# Processing record 44 of set 4 -----> san pedro
# Processing record 45 of set 4 -----> inzhavino
# Processing record 46 of set 4 -----> karaul
# City not found. Skipping...
# Processing record 47 of set 4 -----> matara
# Processing record 48 of set 4 -----> portland
# Processing record 49 of set 4 -----> jardim
# Processing record 50 of set 4 -----> berja
# Processing record 0 of set 5 -----> olafsvik
# City not found. Skipping...
# Processing record 1 of set 5 -----> samusu
# City not found. Skipping...
# Processing record 2 of set 5 -----> husavik
# Processing record 3 of set 5 -----> airai
# Processing record 4 of set 5 -----> evensk
# Processing record 5 of set 5 -----> harlingen
# Processing record 6 of set 5 -----> oudtshoorn
# Processing record 7 of set 5 -----> maarianhamina
# City not found. Skipping...
# Processing record 8 of set 5 -----> port elizabeth
# Processing record 9 of set 5 -----> bubaque
# Processing record 10 of set 5 -----> aanekoski
# Processing record 11 of set 5 -----> siderno
# Processing record 12 of set 5 -----> iqaluit
# Processing record 13 of set 5 -----> lolua
# City not found. Skipping...
# Processing record 14 of set 5 -----> rawson
# Processing record 15 of set 5 -----> kungurtug
# Processing record 16 of set 5 -----> samalaeulu
# City not found. Skipping...
# Processing record 17 of set 5 -----> ancud
# Processing record 18 of set 5 -----> saint george
# Processing record 19 of set 5 -----> san miguel
# Processing record 20 of set 5 -----> takoradi
# Processing record 21 of set 5 -----> santa isabel do rio negro
# Processing record 22 of set 5 -----> tabulbah
# City not found. Skipping...
# Processing record 23 of set 5 -----> victoria
# Processing record 24 of set 5 -----> marzuq
# Processing record 25 of set 5 -----> vestmannaeyjar
# Processing record 26 of set 5 -----> saryozek
# Processing record 27 of set 5 -----> westport
# Processing record 28 of set 5 -----> sherlovaya gora
# Processing record 29 of set 5 -----> sao filipe
# Processing record 30 of set 5 -----> marcona
# City not found. Skipping...
# Processing record 31 of set 5 -----> pointe-noire
# Processing record 32 of set 5 -----> dicabisagan
# Processing record 33 of set 5 -----> attawapiskat
# City not found. Skipping...
# Processing record 34 of set 5 -----> atar
# Processing record 35 of set 5 -----> eydhafushi
# Processing record 36 of set 5 -----> touros
# Processing record 37 of set 5 -----> philippsburg
# Processing record 38 of set 5 -----> beringovskiy
# Processing record 39 of set 5 -----> mutsamudu
# City not found. Skipping...
# Processing record 40 of set 5 -----> goderich
# Processing record 41 of set 5 -----> okhotsk
# Processing record 42 of set 5 -----> sao joao da barra
# Processing record 43 of set 5 -----> synya
# Processing record 44 of set 5 -----> porgera
# Processing record 45 of set 5 -----> mehamn
# Processing record 46 of set 5 -----> mys shmidta
# City not found. Skipping...
# Processing record 47 of set 5 -----> qeshm
# Processing record 48 of set 5 -----> puquio
# Processing record 49 of set 5 -----> coffs harbour
# Processing record 50 of set 5 -----> carutapera
# Processing record 0 of set 6 -----> kruisfontein
# Processing record 1 of set 6 -----> gastello
# Processing record 2 of set 6 -----> thunder bay
# Processing record 3 of set 6 -----> taltal
# Processing record 4 of set 6 -----> langsa
# Processing record 5 of set 6 -----> esperance
# Processing record 6 of set 6 -----> ciudad bolivar
# Processing record 7 of set 6 -----> horsham
# Processing record 8 of set 6 -----> morros
# Processing record 9 of set 6 -----> coahuayana
# Processing record 10 of set 6 -----> lamesa
# Processing record 11 of set 6 -----> megion
# Processing record 12 of set 6 -----> seminole
# Processing record 13 of set 6 -----> passo de camaragibe
# Processing record 14 of set 6 -----> diffa
# Processing record 15 of set 6 -----> nizhneyansk
# City not found. Skipping...
# Processing record 16 of set 6 -----> rio grande
# Processing record 17 of set 6 -----> yerbogachen
# Processing record 18 of set 6 -----> guarapari
# Processing record 19 of set 6 -----> baykit
# Processing record 20 of set 6 -----> acurenam
# Processing record 21 of set 6 -----> mount isa
# Processing record 22 of set 6 -----> bolungarvik
# City not found. Skipping...
# Processing record 23 of set 6 -----> japura
# Processing record 24 of set 6 -----> egvekinot
# Processing record 25 of set 6 -----> batemans bay
# Processing record 26 of set 6 -----> amapa
# Processing record 27 of set 6 -----> comodoro rivadavia
# Processing record 28 of set 6 -----> mnogovershinnyy
# Processing record 29 of set 6 -----> dingle
# Processing record 30 of set 6 -----> zeya
# Processing record 31 of set 6 -----> karatu
# Processing record 32 of set 6 -----> kargasok
# Processing record 33 of set 6 -----> imeni zhelyabova
# Processing record 34 of set 6 -----> ahipara
# Processing record 35 of set 6 -----> thinadhoo
# Processing record 36 of set 6 -----> benghazi
# Processing record 37 of set 6 -----> souillac
# Processing record 38 of set 6 -----> santa rosa
# Processing record 39 of set 6 -----> igarka
# Processing record 40 of set 6 -----> tasiilaq
# Processing record 41 of set 6 -----> kapit
# Processing record 42 of set 6 -----> sharkan
# Processing record 43 of set 6 -----> paamiut
# Processing record 44 of set 6 -----> chandbali
# Processing record 45 of set 6 -----> pareora
# Processing record 46 of set 6 -----> uusikaupunki
# Processing record 47 of set 6 -----> haines junction
# Processing record 48 of set 6 -----> bonthe
# Processing record 49 of set 6 -----> rudnogorsk
# Processing record 50 of set 6 -----> nuevitas
# Processing record 0 of set 7 -----> poum
# Processing record 1 of set 7 -----> urumqi
# City not found. Skipping...
# Processing record 2 of set 7 -----> baijiantan
# Processing record 3 of set 7 -----> tynda
# Processing record 4 of set 7 -----> giyani
# Processing record 5 of set 7 -----> lompoc
# Processing record 6 of set 7 -----> mullaitivu
# City not found. Skipping...
# Processing record 7 of set 7 -----> vostok
# Processing record 8 of set 7 -----> buraydah
# Processing record 9 of set 7 -----> verkhnevilyuysk
# Processing record 10 of set 7 -----> nerja
# Processing record 11 of set 7 -----> adrar
# Processing record 12 of set 7 -----> sobolevo
# Processing record 13 of set 7 -----> talnakh
# Processing record 14 of set 7 -----> rumford
# Processing record 15 of set 7 -----> aksarka
# Processing record 16 of set 7 -----> peterhead
# Processing record 17 of set 7 -----> jiddah
# City not found. Skipping...
# Processing record 18 of set 7 -----> jizan
# Processing record 19 of set 7 -----> turukhansk
# Processing record 20 of set 7 -----> visegrad
# Processing record 21 of set 7 -----> barstow
# Processing record 22 of set 7 -----> cap malheureux
# Processing record 23 of set 7 -----> dzaoudzi
# Processing record 24 of set 7 -----> wairoa
# Processing record 25 of set 7 -----> novopetrovskoye
# Processing record 26 of set 7 -----> leningradskiy
# Processing record 27 of set 7 -----> guaimaro
# Processing record 28 of set 7 -----> kushiro
# Processing record 29 of set 7 -----> jinchang
# Processing record 30 of set 7 -----> kondagaon
# Processing record 31 of set 7 -----> mitu
# Processing record 32 of set 7 -----> birao
# Processing record 33 of set 7 -----> aswan
# Processing record 34 of set 7 -----> balakhta
# Processing record 35 of set 7 -----> buchanan
# Processing record 36 of set 7 -----> wexford
# Processing record 37 of set 7 -----> sovetsk
# Processing record 38 of set 7 -----> port lincoln
# Processing record 39 of set 7 -----> koumac
# Processing record 40 of set 7 -----> wanlaweyn
# Processing record 41 of set 7 -----> ixtapa
# Processing record 42 of set 7 -----> zwedru
# Processing record 43 of set 7 -----> najran
# Processing record 44 of set 7 -----> iquique
# Processing record 45 of set 7 -----> phalaborwa
# Processing record 46 of set 7 -----> half moon bay
# Processing record 47 of set 7 -----> kamina
# Processing record 48 of set 7 -----> narsaq
# Processing record 49 of set 7 -----> moyale
# Processing record 50 of set 7 -----> umm durman
# City not found. Skipping...
# Processing record 0 of set 8 -----> fukue
# Processing record 1 of set 8 -----> grindavik
# Processing record 2 of set 8 -----> liverpool
# Processing record 3 of set 8 -----> kondinskoye
# Processing record 4 of set 8 -----> dabat
# Processing record 5 of set 8 -----> nemuro
# Processing record 6 of set 8 -----> san ramon
# Processing record 7 of set 8 -----> chopinzinho
# Processing record 8 of set 8 -----> ottawa
# Processing record 9 of set 8 -----> ibra
# Processing record 10 of set 8 -----> amahai
# Processing record 11 of set 8 -----> wagar
# Processing record 12 of set 8 -----> killam
# Processing record 13 of set 8 -----> prado
# Processing record 14 of set 8 -----> mahaicony
# City not found. Skipping...
# Processing record 15 of set 8 -----> anadyr
# Processing record 16 of set 8 -----> porto walter
# Processing record 17 of set 8 -----> bathsheba
# Processing record 18 of set 8 -----> ushtobe
# Processing record 19 of set 8 -----> limoux
# Processing record 20 of set 8 -----> mildura
# Processing record 21 of set 8 -----> srivardhan
# Processing record 22 of set 8 -----> slave lake
# Processing record 23 of set 8 -----> hasaki
# Processing record 24 of set 8 -----> karkaralinsk
# City not found. Skipping...
# Processing record 25 of set 8 -----> fereydun kenar
# Processing record 26 of set 8 -----> ketchikan
# Processing record 27 of set 8 -----> pizarro
# Processing record 28 of set 8 -----> nouadhibou
# Processing record 29 of set 8 -----> prince george
# Processing record 30 of set 8 -----> pindiga
# Processing record 31 of set 8 -----> tiznit
# Processing record 32 of set 8 -----> lavrentiya
# Processing record 33 of set 8 -----> risod
# Processing record 34 of set 8 -----> antalaha
# Processing record 35 of set 8 -----> khovu-aksy
# Processing record 36 of set 8 -----> ishigaki
# Processing record 37 of set 8 -----> yatou
# Processing record 38 of set 8 -----> sosnovo-ozerskoye
# Processing record 39 of set 8 -----> san-pedro
# Processing record 40 of set 8 -----> lipari
# Processing record 41 of set 8 -----> roros
# Processing record 42 of set 8 -----> longyearbyen
# Processing record 43 of set 8 -----> bath
# Processing record 44 of set 8 -----> boa vista
# Processing record 45 of set 8 -----> masuguru
# Processing record 46 of set 8 -----> along
# Processing record 47 of set 8 -----> solntsevo
# Processing record 48 of set 8 -----> nanortalik
# Processing record 49 of set 8 -----> tabuk
# Processing record 50 of set 8 -----> berezovyy
# Processing record 0 of set 9 -----> inhambane
# Processing record 1 of set 9 -----> tungkang
# City not found. Skipping...
# Processing record 2 of set 9 -----> guayaramerin
# Processing record 3 of set 9 -----> linapacan
# City not found. Skipping...
# Processing record 4 of set 9 -----> sfantu gheorghe
# Processing record 5 of set 9 -----> saint anthony
# Processing record 6 of set 9 -----> polyanka
# Processing record 7 of set 9 -----> tabiauea
# City not found. Skipping...
# Processing record 8 of set 9 -----> severo-yeniseyskiy
# Processing record 9 of set 9 -----> bremervorde
# Processing record 10 of set 9 -----> banda aceh
# Processing record 11 of set 9 -----> santa cruz
# Processing record 12 of set 9 -----> avera
# Processing record 13 of set 9 -----> merauke
# Processing record 14 of set 9 -----> la paz centro
# Processing record 15 of set 9 -----> hirara
# Processing record 16 of set 9 -----> coihaique
# Processing record 17 of set 9 -----> homer
# Processing record 18 of set 9 -----> grand gaube
# Processing record 19 of set 9 -----> ust-maya
# Processing record 20 of set 9 -----> novobelokatay
# Processing record 21 of set 9 -----> mala
# Processing record 22 of set 9 -----> gemenele
# Processing record 23 of set 9 -----> shima
# Processing record 24 of set 9 -----> dieppe
# Processing record 25 of set 9 -----> pulandian
# Processing record 26 of set 9 -----> oksfjord
# Processing record 27 of set 9 -----> nabire
# Processing record 28 of set 9 -----> mayor pablo lagerenza
# Processing record 29 of set 9 -----> sistranda
# Processing record 30 of set 9 -----> bontang
# Processing record 31 of set 9 -----> azuaga
# Processing record 32 of set 9 -----> horta
# Processing record 33 of set 9 -----> ipixuna
# Processing record 34 of set 9 -----> kharp
# Processing record 35 of set 9 -----> lakes entrance
# Processing record 36 of set 9 -----> ponta delgada
# Processing record 37 of set 9 -----> kutum
# Processing record 38 of set 9 -----> sao raimundo das mangabeiras
# Processing record 39 of set 9 -----> winnemucca
# Processing record 40 of set 9 -----> saint-denis
# Processing record 41 of set 9 -----> bani walid
# Processing record 42 of set 9 -----> timmins
# Processing record 43 of set 9 -----> cartagena del chaira
# Processing record 44 of set 9 -----> petropavlovsk-kamchatskiy
# Processing record 45 of set 9 -----> nahariyya
# Processing record 46 of set 9 -----> sungairaya
# Processing record 47 of set 9 -----> viedma
# Processing record 48 of set 9 -----> mossendjo
# Processing record 49 of set 9 -----> pokosnoye
# Processing record 50 of set 9 -----> morro bay
# Processing record 0 of set 10 -----> alpena
# Processing record 1 of set 10 -----> port hardy
# Processing record 2 of set 10 -----> sapao
# City not found. Skipping...
# Processing record 3 of set 10 -----> koson
# Processing record 4 of set 10 -----> fort nelson
# Processing record 5 of set 10 -----> havre-saint-pierre
# Processing record 6 of set 10 -----> vila franca do campo
# Processing record 7 of set 10 -----> hastings
# Processing record 8 of set 10 -----> maniwaki
# Processing record 9 of set 10 -----> bayan
# Processing record 10 of set 10 -----> schongau
# Processing record 11 of set 10 -----> mariestad
# Processing record 12 of set 10 -----> presidente epitacio
# Processing record 13 of set 10 -----> pisco
# Processing record 14 of set 10 -----> mogadishu
# Processing record 15 of set 10 -----> kamenka
# Processing record 16 of set 10 -----> tagusao
# Processing record 17 of set 10 -----> matiri
# Processing record 18 of set 10 -----> acarau
# City not found. Skipping...
# Processing record 19 of set 10 -----> ola
# Processing record 20 of set 10 -----> ciudad real
# Processing record 21 of set 10 -----> abdanan
# Processing record 22 of set 10 -----> kendari
# Processing record 23 of set 10 -----> namibe
# Processing record 24 of set 10 -----> ilhabela
# Processing record 25 of set 10 -----> monte alegre
# Processing record 26 of set 10 -----> ambanja
# Processing record 27 of set 10 -----> biltine
# Processing record 28 of set 10 -----> davila
# Processing record 29 of set 10 -----> taksimo
# Processing record 30 of set 10 -----> tucurui
# Processing record 31 of set 10 -----> haibowan
# City not found. Skipping...
# Processing record 32 of set 10 -----> maniitsoq
# Processing record 33 of set 10 -----> zhezkazgan
# Processing record 34 of set 10 -----> bayanday
# Processing record 35 of set 10 -----> pathein
# Processing record 36 of set 10 -----> altos
# Processing record 37 of set 10 -----> presidencia roque saenz pena
# Processing record 38 of set 10 -----> banjar
# Processing record 39 of set 10 -----> zhigansk
# Processing record 40 of set 10 -----> guilin
# Processing record 41 of set 10 -----> santa rosalia
# Processing record 42 of set 10 -----> gangotri
# City not found. Skipping...
# Processing record 43 of set 10 -----> piryion
# City not found. Skipping...
# Processing record 44 of set 10 -----> savelugu
# Processing record 45 of set 10 -----> lagunas
# Processing record 46 of set 10 -----> macau
# Processing record 47 of set 10 -----> alofi
# Processing record 48 of set 10 -----> abu samrah
# Processing record 49 of set 10 -----> lamar
# Processing record 50 of set 10 -----> jumla
# Processing record 0 of set 11 -----> vao
# Processing record 1 of set 11 -----> hokitika
# Processing record 2 of set 11 -----> kununurra
# Processing record 3 of set 11 -----> el tigre
# Processing record 4 of set 11 -----> elko
# Processing record 5 of set 11 -----> maria aurora
# Processing record 6 of set 11 -----> pyay
# Processing record 7 of set 11 -----> carhuamayo
# Processing record 8 of set 11 -----> ambilobe
# Processing record 9 of set 11 -----> rungata
# City not found. Skipping...
# Processing record 10 of set 11 -----> awjilah
# Processing record 11 of set 11 -----> vila velha
# Processing record 12 of set 11 -----> koshurnikovo
# Processing record 13 of set 11 -----> benguela
# Processing record 14 of set 11 -----> sao felix do xingu
# Processing record 15 of set 11 -----> raudeberg
# Processing record 16 of set 11 -----> tumannyy
# City not found. Skipping...
# Processing record 17 of set 11 -----> veshenskaya
# Processing record 18 of set 11 -----> concarneau
# Processing record 19 of set 11 -----> port keats
# Processing record 20 of set 11 -----> zhenlai
# Processing record 21 of set 11 -----> perisoru
# Processing record 22 of set 11 -----> bochil
# Processing record 23 of set 11 -----> surman
# Processing record 24 of set 11 -----> roebourne
# Processing record 25 of set 11 -----> kamaishi
# Processing record 26 of set 11 -----> sarangani
# Processing record 27 of set 11 -----> oyek
# Processing record 28 of set 11 -----> noyabrsk
# Processing record 29 of set 11 -----> qasigiannguit
# Processing record 30 of set 11 -----> louisbourg
# City not found. Skipping...
# Processing record 31 of set 11 -----> north myrtle beach
# Processing record 32 of set 11 -----> neiafu
# Processing record 33 of set 11 -----> gigmoto
# ---------------------------------------------------------------------------------

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
df_prep = {"City": cityxyz, "Cloudiness" : cloudiness, "Country" : country,
           "Date" : date, "Humidity" : humidity, "Temp": temperature, 
           "Lat" : latitude, "Lng" : longitude, "Wind Speed" : windspeed}
dataframe = pd.DataFrame(df_prep)

# %%
dataframe.count()
# Out:
# City          545
# Cloudiness    545
# Country       545
# Date          545
# Humidity      545
# Temp          545
# Lat           545
# Lng           545
# Wind Speed    545
# dtype: int64

# %%
dataframe.head(10)
# Out:
#             City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0       hamilton          75      CA  1569310513        87  62.01  43.26
# 1      busselton           1      AU  1569310685        40  73.99 -33.64
# 2        rikitea         100      PF  1569310685        72  69.70 -23.12
# 3           roma           0      IT  1569310491        93  70.00  41.89
# 4      jamestown           0      AU  1569310686        75  49.00 -33.21
# 5          sitka           0      US  1569310686        93  69.01  37.17
# 6  pacific grove           1      US  1569310686        72  66.99  36.62
# 7         sabang         100      PH  1569310687        70  89.01  13.80
# 8        sibolga         100      ID  1569310687        84  81.58   1.74
# 9     launceston          90      AU  1569310687        50  57.20 -41.43
#
#       Lng  Wind Speed
# 0  -79.87        8.05
# 1  115.35        9.28
# 2 -134.97       12.33
# 3   12.48        1.12
# 4  138.60        8.10
# 5  -99.65        8.99
# 6 -121.92        8.28
# 7  121.11        4.00
# 8   98.78       18.28
# 9  147.14       14.99

# %%
#https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python?utm_source=adwords_ppc&utm_campaignid=1565261270&utm_adgroupid=67750485268&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=1t1&utm_creative=332661264371&utm_targetid=aud-299261629574:dsa-473406573835&utm_loc_interest_ms=&utm_loc_physical_ms=9032185&gclid=Cj0KCQjw_absBRD1ARIsAO4_D3ujei8ii4exnm5AoO-GUSrn2FRg9rrVX7OAA7ruNkMoFofVxcL-_ZYaAoHvEALw_wcB#question11
dataframe.to_csv('../Output/citydata.csv', sep='\t', encoding='utf-8')

# %%
plt.scatter(dataframe["Lat"], dataframe["Temp"], marker="o")

plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Temperature")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()
